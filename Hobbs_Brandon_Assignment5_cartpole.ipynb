# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.9275689688183278, score: 21
# Scores: (min: 14, avg: 17.5, max: 21)
#
# Run: 3, exploration: 0.7552531090661897, score: 42
# Scores: (min: 14, avg: 25.666666666666668, max: 42)
#
# Run: 4, exploration: 0.7147372386831305, score: 12
# Scores: (min: 12, avg: 22.25, max: 42)
#
# Run: 5, exploration: 0.6730128848950395, score: 13
# Scores: (min: 12, avg: 20.4, max: 42)
#
# Run: 6, exploration: 0.6465587967553006, score: 9
# Scores: (min: 9, avg: 18.5, max: 42)
#
# Run: 7, exploration: 0.6088145090359074, score: 13
# Scores: (min: 9, avg: 17.714285714285715, max: 42)
#
# Run: 8, exploration: 0.547986285490042, score: 22
# Scores: (min: 9, avg: 18.25, max: 42)
#
# Run: 9, exploration: 0.5264466124450268, score: 9
# Scores: (min: 9, avg: 17.22222222222222, max: 42)
#
# Run: 10, exploration: 0.4858739637363176, score: 17
# Scores: (min: 9, avg: 17.2, max: 42)
#
# Run: 11, exploration: 0.46211964903917074, score: 11
# Scores: (min: 9, avg: 16.636363636363637, max: 42)
#
# Run: 12, exploration: 0.43952667968844233, score: 11
# Scores: (min: 9, avg: 16.166666666666668, max: 42)
#
# Run: 13, exploration: 0.4222502236424958, score: 9
# Scores: (min: 9, avg: 15.615384615384615, max: 42)
#
# Run: 14, exploration: 0.40565285250151817, score: 9
# Scores: (min: 9, avg: 15.142857142857142, max: 42)
#
# Run: 15, exploration: 0.37816180712868996, score: 15
# Scores: (min: 9, avg: 15.133333333333333, max: 42)
#
# Run: 16, exploration: 0.3614809303671764, score: 10
# Scores: (min: 9, avg: 14.8125, max: 42)
#
# Run: 17, exploration: 0.3386767948568688, score: 14
# Scores: (min: 9, avg: 14.764705882352942, max: 42)
#
# Run: 18, exploration: 0.3253644408394192, score: 9
# Scores: (min: 9, avg: 14.444444444444445, max: 42)
#
# Run: 19, exploration: 0.3063705780533402, score: 13
# Scores: (min: 9, avg: 14.368421052631579, max: 42)
#
# Run: 20, exploration: 0.29580711868545667, score: 8
# Scores: (min: 8, avg: 14.05, max: 42)
#
# Run: 21, exploration: 0.2757603055760701, score: 15
# Scores: (min: 8, avg: 14.095238095238095, max: 42)
#
# Run: 22, exploration: 0.26359640222486147, score: 10
# Scores: (min: 8, avg: 13.909090909090908, max: 42)
#
# Run: 23, exploration: 0.2507092085103961, score: 11
# Scores: (min: 8, avg: 13.782608695652174, max: 42)
#
# Run: 24, exploration: 0.23965031961336, score: 10
# Scores: (min: 8, avg: 13.625, max: 42)
#
# Run: 25, exploration: 0.22679417751985861, score: 12
# Scores: (min: 8, avg: 13.56, max: 42)
#
# Run: 26, exploration: 0.2167901907234072, score: 10
# Scores: (min: 8, avg: 13.423076923076923, max: 42)
#
# Run: 27, exploration: 0.2041345879004775, score: 13
# Scores: (min: 8, avg: 13.407407407407407, max: 42)
#
# Run: 28, exploration: 0.19318370215794672, score: 12
# Scores: (min: 8, avg: 13.357142857142858, max: 42)
#
# Run: 29, exploration: 0.18559023879528855, score: 9
# Scores: (min: 8, avg: 13.206896551724139, max: 42)
#
# Run: 30, exploration: 0.17829525136613786, score: 9
# Scores: (min: 8, avg: 13.066666666666666, max: 42)
#
# Run: 31, exploration: 0.17043057265153258, score: 10
# Scores: (min: 8, avg: 12.96774193548387, max: 42)
#
# Run: 32, exploration: 0.16373146555890544, score: 9
# Scores: (min: 8, avg: 12.84375, max: 42)
#
# Run: 33, exploration: 0.1572956799768517, score: 9
# Scores: (min: 8, avg: 12.727272727272727, max: 42)
#
# Run: 34, exploration: 0.15111286553822956, score: 9
# Scores: (min: 8, avg: 12.617647058823529, max: 42)
#
# Run: 35, exploration: 0.1451730787173275, score: 9
# Scores: (min: 8, avg: 12.514285714285714, max: 42)
#
# Run: 36, exploration: 0.14016760486247823, score: 8
# Scores: (min: 8, avg: 12.38888888888889, max: 42)
#
# Run: 37, exploration: 0.1346580429260134, score: 9
# Scores: (min: 8, avg: 12.297297297297296, max: 42)
#
# Run: 38, exploration: 0.12871821987500112, score: 10
# Scores: (min: 8, avg: 12.236842105263158, max: 42)
#
# Run: 39, exploration: 0.12365869841532712, score: 9
# Scores: (min: 8, avg: 12.153846153846153, max: 42)
#
# Run: 40, exploration: 0.053006034755694834, score: 170
# Scores: (min: 8, avg: 16.1, max: 170)
#
# Run: 41, exploration: 0.041670929977297724, score: 49
# Scores: (min: 8, avg: 16.902439024390244, max: 170)
#
# Run: 42, exploration: 0.032924408985721944, score: 48
# Scores: (min: 8, avg: 17.642857142857142, max: 170)
#
# Run: 43, exploration: 0.023769400938086327, score: 66
# Scores: (min: 8, avg: 18.767441860465116, max: 170)
#
# Run: 44, exploration: 0.016988875991640028, score: 68
# Scores: (min: 8, avg: 19.886363636363637, max: 170)
#
# Run: 45, exploration: 0.01166529436067347, score: 76
# Scores: (min: 8, avg: 21.133333333333333, max: 170)
#
# Run: 46, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 21.891304347826086, max: 170)
#
# Run: 47, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 22.23404255319149, max: 170)
#
# Run: 48, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 23.145833333333332, max: 170)
#
# Run: 49, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 24.387755102040817, max: 170)
#
# Run: 50, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 25.34, max: 170)
#
# Run: 51, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 26.215686274509803, max: 170)
#
# Run: 52, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 27.23076923076923, max: 170)
#
# Run: 53, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 27.735849056603772, max: 170)
#
# Run: 54, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 28.296296296296298, max: 170)
#
# Run: 55, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 28.836363636363636, max: 170)
#
# Run: 56, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 29.642857142857142, max: 170)
#
# Run: 57, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 30.63157894736842, max: 170)
#
# Run: 58, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 30.620689655172413, max: 170)
#
# Run: 59, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 31.220338983050848, max: 170)
#
# Run: 60, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 31.633333333333333, max: 170)
#
# Run: 61, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 31.950819672131146, max: 170)
#
# Run: 62, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 32.29032258064516, max: 170)
#
# Run: 63, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 33.06349206349206, max: 170)
#
# Run: 64, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 34.015625, max: 170)
#
# Run: 65, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 35.90769230769231, max: 170)
#
# Run: 66, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 37.36363636363637, max: 170)
#
# Run: 67, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 38.61194029850746, max: 170)
#
# Run: 68, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 39.61764705882353, max: 170)
#
# Run: 69, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 41.231884057971016, max: 170)
#
# Run: 70, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 42.52857142857143, max: 170)
#
# Run: 71, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 44.070422535211264, max: 170)
#
# Run: 72, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 46.791666666666664, max: 240)
#
# Run: 73, exploration: 0.01, score: 337
# Scores: (min: 8, avg: 50.76712328767123, max: 337)
#
# Run: 74, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 53.986486486486484, max: 337)
#
# Run: 75, exploration: 0.01, score: 372
# Scores: (min: 8, avg: 58.22666666666667, max: 372)
#
# Run: 76, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 60.96052631578947, max: 372)
#
# Run: 77, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 63.61038961038961, max: 372)
#
# Run: 78, exploration: 0.01, score: 335
# Scores: (min: 8, avg: 67.08974358974359, max: 372)
#
# Run: 79, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 67.46835443037975, max: 372)
#
# Run: 80, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 67.5, max: 372)
#
# Run: 81, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 69.19753086419753, max: 372)
#
# Run: 82, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 70.8048780487805, max: 372)
#
# Run: 83, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 71.49397590361446, max: 372)
#
# Run: 84, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 72.27380952380952, max: 372)
#
# Run: 85, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 73.76470588235294, max: 372)
#
# Run: 86, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 75.25581395348837, max: 372)
# Run: 87, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 76.6896551724138, max: 372)
#
# Run: 88, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 78.14772727272727, max: 372)
#
# Run: 89, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 79.49438202247191, max: 372)
#
# Run: 90, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 79.35555555555555, max: 372)
#
# Run: 91, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 80.6923076923077, max: 372)
#
# Run: 92, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 80.21739130434783, max: 372)
#
# Run: 93, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 80.84946236559139, max: 372)
#
# Run: 94, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 82, max: 372)
#
# Run: 95, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 83.02105263157895, max: 372)
#
# Run: 96, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 84.39583333333333, max: 372)
#
# Run: 97, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 85.80412371134021, max: 372)
#
# Run: 98, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 86.75510204081633, max: 372)
#
# Run: 99, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 87.94949494949495, max: 372)
#
# Run: 100, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 89.55, max: 372)
#
# Run: 101, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 90.59, max: 372)
#
# Run: 102, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 92.17, max: 372)
#
# Run: 103, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 94.38, max: 372)
#
# Run: 104, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 95.2, max: 372)
#
# Run: 105, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 97.59, max: 372)
#
# Run: 106, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 99.3, max: 372)
#
# Run: 107, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 100.74, max: 372)
#
# Run: 108, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 102.71, max: 372)
#
# Run: 109, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 104.3, max: 372)
#
# Run: 110, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 106.07, max: 372)
#
# Run: 111, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 107.3, max: 372)
#
# Run: 112, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 109.33, max: 372)
#
# Run: 113, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 110.9, max: 372)
#
# Run: 114, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 111.8, max: 372)
#
# Run: 115, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 113.23, max: 372)
#
# Run: 116, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 115.15, max: 372)
#
# Run: 117, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 116.59, max: 372)
#
# Run: 118, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 118.29, max: 372)
#
# Run: 119, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 120.32, max: 372)
#
# Run: 120, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 121.79, max: 372)
#
# Run: 121, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 122.98, max: 372)
#
# Run: 122, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 124.2, max: 372)
#
# Run: 123, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 126.06, max: 372)
#
# Run: 124, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 127.89, max: 372)
#
# Run: 125, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 129.55, max: 372)
#
# Run: 126, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 131.93, max: 372)
#
# Run: 127, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 132.88, max: 372)
#
# Run: 128, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 134.31, max: 372)
#
# Run: 129, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 136.53, max: 372)
#
# Run: 130, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 138.32, max: 372)
#
# Run: 131, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 139.42, max: 372)
#
# Run: 132, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 142.22, max: 372)
#
# Run: 133, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 143.76, max: 372)
#
# Run: 134, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 144.56, max: 372)
#
# Run: 135, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 146.67, max: 372)
#
# Run: 136, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 147.82, max: 372)
#
# Run: 137, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 148.89, max: 372)
#
# Run: 138, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 150.73, max: 372)
#
# Run: 139, exploration: 0.01, score: 162
# Scores: (min: 30, avg: 152.26, max: 372)
#
# Run: 140, exploration: 0.01, score: 224
# Scores: (min: 30, avg: 152.8, max: 372)
#
# Run: 141, exploration: 0.01, score: 129
# Scores: (min: 30, avg: 153.6, max: 372)
#
# Run: 142, exploration: 0.01, score: 153
# Scores: (min: 30, avg: 154.65, max: 372)
#
# Run: 143, exploration: 0.01, score: 195
# Scores: (min: 30, avg: 155.94, max: 372)
#
# Run: 144, exploration: 0.01, score: 181
# Scores: (min: 30, avg: 157.07, max: 372)
#
# Run: 145, exploration: 0.01, score: 127
# Scores: (min: 30, avg: 157.58, max: 372)
#
# Run: 146, exploration: 0.01, score: 136
# Scores: (min: 30, avg: 158.38, max: 372)
#
# Run: 147, exploration: 0.01, score: 321
# Scores: (min: 30, avg: 161.21, max: 372)
#
# Run: 148, exploration: 0.01, score: 325
# Scores: (min: 30, avg: 163.8, max: 372)
#
# Run: 149, exploration: 0.01, score: 144
# Scores: (min: 30, avg: 164.4, max: 372)
#
# Run: 150, exploration: 0.01, score: 131
# Scores: (min: 30, avg: 164.99, max: 372)
#
# Run: 151, exploration: 0.01, score: 24
# Scores: (min: 24, avg: 164.53, max: 372)
#
# Run: 152, exploration: 0.01, score: 116
# Scores: (min: 24, avg: 164.9, max: 372)
#
# Run: 153, exploration: 0.01, score: 131
# Scores: (min: 24, avg: 165.67, max: 372)
#
# Run: 154, exploration: 0.01, score: 239
# Scores: (min: 24, avg: 167.48, max: 372)
#
# Run: 155, exploration: 0.01, score: 343
# Scores: (min: 24, avg: 170.33, max: 372)
#
# Run: 156, exploration: 0.01, score: 149
# Scores: (min: 24, avg: 171.08, max: 372)
#
# Run: 157, exploration: 0.01, score: 154
# Scores: (min: 24, avg: 171.76, max: 372)
#
# Run: 158, exploration: 0.01, score: 142
# Scores: (min: 24, avg: 172.88, max: 372)
#
# Run: 159, exploration: 0.01, score: 353
# Scores: (min: 24, avg: 175.75, max: 372)
#
# Run: 160, exploration: 0.01, score: 210
# Scores: (min: 24, avg: 177.29, max: 372)
#
# Run: 161, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 176.94, max: 372)
#
# Run: 162, exploration: 0.01, score: 303
# Scores: (min: 16, avg: 179.44, max: 372)
#
# Run: 163, exploration: 0.01, score: 111
# Scores: (min: 16, avg: 179.74, max: 372)
#
# Run: 164, exploration: 0.01, score: 271
# Scores: (min: 16, avg: 181.51, max: 372)
#
# Run: 165, exploration: 0.01, score: 187
# Scores: (min: 16, avg: 181.81, max: 372)
#
# Run: 166, exploration: 0.01, score: 439
# Scores: (min: 16, avg: 184.88, max: 439)
#
# Run: 167, exploration: 0.01, score: 116
# Scores: (min: 16, avg: 184.83, max: 439)
#
# Run: 168, exploration: 0.01, score: 135
# Scores: (min: 16, avg: 185.11, max: 439)
#
# Run: 169, exploration: 0.01, score: 252
# Scores: (min: 16, avg: 186.12, max: 439)
#
# Run: 170, exploration: 0.01, score: 151
# Scores: (min: 16, avg: 186.31, max: 439)
#
# Run: 171, exploration: 0.01, score: 358
# Scores: (min: 16, avg: 188.37, max: 439)
#
# Run: 172, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 186.13, max: 439)
#
# Run: 173, exploration: 0.01, score: 15
# Scores: (min: 15, avg: 182.91, max: 439)
#
# Run: 174, exploration: 0.01, score: 170
# Scores: (min: 15, avg: 181.72, max: 439)
#
# Run: 175, exploration: 0.01, score: 223
# Scores: (min: 15, avg: 180.23, max: 439)
#
# Run: 176, exploration: 0.01, score: 119
# Scores: (min: 15, avg: 178.76, max: 439)
#
# Run: 177, exploration: 0.01, score: 204
# Scores: (min: 15, avg: 178.15, max: 439)
#
# Run: 178, exploration: 0.01, score: 108
# Scores: (min: 15, avg: 175.88, max: 439)
#
# Run: 179, exploration: 0.01, score: 121
# Scores: (min: 15, avg: 176.12, max: 439)
#
# Run: 180, exploration: 0.01, score: 261
# Scores: (min: 15, avg: 178.03, max: 439)
#
# Run: 181, exploration: 0.01, score: 63
# Scores: (min: 15, avg: 176.61, max: 439)
#
# Run: 182, exploration: 0.01, score: 290
# Scores: (min: 15, avg: 177.5, max: 439)
#
# Run: 183, exploration: 0.01, score: 485
# Scores: (min: 15, avg: 181.07, max: 485)
#
# Run: 184, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 184.7, max: 500)
#
# Run: 185, exploration: 0.01, score: 131
# Scores: (min: 15, avg: 184.02, max: 500)
#
# Run: 186, exploration: 0.01, score: 187
# Scores: (min: 15, avg: 183.87, max: 500)
# Run: 187, exploration: 0.01, score: 273
# Scores: (min: 15, avg: 184.6, max: 500)
#
# Run: 188, exploration: 0.01, score: 115
# Scores: (min: 15, avg: 183.7, max: 500)
#
# Run: 189, exploration: 0.01, score: 120
# Scores: (min: 15, avg: 182.92, max: 500)
#
# Run: 190, exploration: 0.01, score: 138
# Scores: (min: 15, avg: 183.63, max: 500)
#
# Run: 191, exploration: 0.01, score: 64
# Scores: (min: 15, avg: 182.26, max: 500)
#
# Run: 192, exploration: 0.01, score: 174
# Scores: (min: 15, avg: 183.63, max: 500)
#
# Run: 193, exploration: 0.01, score: 138
# Scores: (min: 15, avg: 183.62, max: 500)
#
# Run: 194, exploration: 0.01, score: 191
# Scores: (min: 15, avg: 183.64, max: 500)
#
# Run: 195, exploration: 0.01, score: 154
# Scores: (min: 15, avg: 183.39, max: 500)
#
# Run: 196, exploration: 0.01, score: 309
# Scores: (min: 15, avg: 184.33, max: 500)
#
# Run: 197, exploration: 0.01, score: 198
# Scores: (min: 15, avg: 184.1, max: 500)
#
# Run: 198, exploration: 0.01, score: 144
# Scores: (min: 15, avg: 183.75, max: 500)
#
# Run: 199, exploration: 0.01, score: 157
# Scores: (min: 15, avg: 183.27, max: 500)
#
# Run: 200, exploration: 0.01, score: 186
# Scores: (min: 15, avg: 182.65, max: 500)
#
# Run: 201, exploration: 0.01, score: 131
# Scores: (min: 15, avg: 182.78, max: 500)
#
# Run: 202, exploration: 0.01, score: 125
# Scores: (min: 15, avg: 182.24, max: 500)
#
# Run: 203, exploration: 0.01, score: 389
# Scores: (min: 15, avg: 183.5, max: 500)
#
# Run: 204, exploration: 0.01, score: 402
# Scores: (min: 15, avg: 186.58, max: 500)
#
# Run: 205, exploration: 0.01, score: 67
# Scores: (min: 15, avg: 184.73, max: 500)
#
# Run: 206, exploration: 0.01, score: 104
# Scores: (min: 15, avg: 183.97, max: 500)
#
# Run: 207, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 187.4, max: 500)
#
# Run: 208, exploration: 0.01, score: 78
# Scores: (min: 15, avg: 185.99, max: 500)
#
# Run: 209, exploration: 0.01, score: 139
# Scores: (min: 15, avg: 185.7, max: 500)
#
# Run: 210, exploration: 0.01, score: 304
# Scores: (min: 15, avg: 186.8, max: 500)
#
# Run: 211, exploration: 0.01, score: 215
# Scores: (min: 15, avg: 187.61, max: 500)
#
# Run: 212, exploration: 0.01, score: 176
# Scores: (min: 15, avg: 187.23, max: 500)
#
# Run: 213, exploration: 0.01, score: 271
# Scores: (min: 15, avg: 188.28, max: 500)
#
# Run: 214, exploration: 0.01, score: 169
# Scores: (min: 15, avg: 188.98, max: 500)
#
# Run: 215, exploration: 0.01, score: 145
# Scores: (min: 15, avg: 188.85, max: 500)
#
# Run: 216, exploration: 0.01, score: 152
# Scores: (min: 15, avg: 188.35, max: 500)
#
# Run: 217, exploration: 0.01, score: 271
# Scores: (min: 15, avg: 189.48, max: 500)
#
# Run: 218, exploration: 0.01, score: 126
# Scores: (min: 15, avg: 188.95, max: 500)
#
# Run: 219, exploration: 0.01, score: 37
# Scores: (min: 15, avg: 187.16, max: 500)
#
# Run: 220, exploration: 0.01, score: 351
# Scores: (min: 15, avg: 189.12, max: 500)
#
# Run: 221, exploration: 0.01, score: 266
# Scores: (min: 15, avg: 190.44, max: 500)
#
# Run: 222, exploration: 0.01, score: 186
# Scores: (min: 15, avg: 190.98, max: 500)
#
# Run: 223, exploration: 0.01, score: 347
# Scores: (min: 15, avg: 192.48, max: 500)
#
# Run: 224, exploration: 0.01, score: 178
# Scores: (min: 15, avg: 192.33, max: 500)
#
# Run: 225, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 195.55, max: 500)
#
# Solved in 125 runs, 225 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.0001  #change the learning rate to smaller
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.9416228069143757, score: 18
# Scores: (min: 14, avg: 16, max: 18)
#
# Run: 3, exploration: 0.8955869907338783, score: 11
# Scores: (min: 11, avg: 14.333333333333334, max: 18)
#
# Run: 4, exploration: 0.8224322824348486, score: 18
# Scores: (min: 11, avg: 15.25, max: 18)
#
# Run: 5, exploration: 0.7514768435208588, score: 19
# Scores: (min: 11, avg: 16, max: 19)
#
# Run: 6, exploration: 0.7147372386831305, score: 11
# Scores: (min: 11, avg: 15.166666666666666, max: 19)
#
# Run: 7, exploration: 0.6730128848950395, score: 13
# Scores: (min: 11, avg: 14.857142857142858, max: 19)
#
# Run: 8, exploration: 0.6433260027715241, score: 10
# Scores: (min: 10, avg: 14.25, max: 19)
#
# Run: 9, exploration: 0.5562889678716474, score: 30
# Scores: (min: 10, avg: 16, max: 30)
#
# Run: 10, exploration: 0.5264466124450268, score: 12
# Scores: (min: 10, avg: 15.6, max: 30)
#
# Run: 11, exploration: 0.500708706245853, score: 11
# Scores: (min: 10, avg: 15.181818181818182, max: 30)
#
# Run: 12, exploration: 0.4738479773082268, score: 12
# Scores: (min: 10, avg: 14.916666666666666, max: 30)
#
# Run: 13, exploration: 0.43952667968844233, score: 16
# Scores: (min: 10, avg: 15, max: 30)
#
# Run: 14, exploration: 0.40974000909221303, score: 15
# Scores: (min: 10, avg: 15, max: 30)
#
# Run: 15, exploration: 0.39166620452737816, score: 10
# Scores: (min: 10, avg: 14.666666666666666, max: 30)
#
# Run: 16, exploration: 0.37251769488706843, score: 11
# Scores: (min: 10, avg: 14.4375, max: 30)
#
# Run: 17, exploration: 0.3507711574848344, score: 13
# Scores: (min: 10, avg: 14.352941176470589, max: 30)
#
# Run: 18, exploration: 0.3352984938281715, score: 10
# Scores: (min: 10, avg: 14.11111111111111, max: 30)
#
# Run: 19, exploration: 0.3173112652388396, score: 12
# Scores: (min: 10, avg: 14, max: 30)
#
# Run: 20, exploration: 0.3033145315372582, score: 10
# Scores: (min: 10, avg: 13.8, max: 30)
#
# Run: 21, exploration: 0.28993519966087045, score: 10
# Scores: (min: 10, avg: 13.619047619047619, max: 30)
#
# Run: 22, exploration: 0.2757603055760701, score: 11
# Scores: (min: 10, avg: 13.5, max: 30)
#
# Run: 23, exploration: 0.26359640222486147, score: 10
# Scores: (min: 10, avg: 13.347826086956522, max: 30)
#
# Run: 24, exploration: 0.2494556624678441, score: 12
# Scores: (min: 10, avg: 13.291666666666666, max: 30)
#
# Run: 25, exploration: 0.23607350863684065, score: 12
# Scores: (min: 10, avg: 13.24, max: 30)
#
# Run: 26, exploration: 0.22566020663225933, score: 10
# Scores: (min: 10, avg: 13.115384615384615, max: 30)
#
# Run: 27, exploration: 0.21355457002808648, score: 12
# Scores: (min: 10, avg: 13.074074074074074, max: 30)
#
# Run: 28, exploration: 0.20516038984972615, score: 9
# Scores: (min: 9, avg: 12.928571428571429, max: 30)
#
# Run: 29, exploration: 0.19415447453059972, score: 12
# Scores: (min: 9, avg: 12.89655172413793, max: 30)
#
# Run: 30, exploration: 0.1846622876013121, score: 11
# Scores: (min: 9, avg: 12.833333333333334, max: 30)
#
# Run: 31, exploration: 0.17651675623376062, score: 10
# Scores: (min: 9, avg: 12.741935483870968, max: 30)
#
# Run: 32, exploration: 0.1662122034722543, score: 13
# Scores: (min: 9, avg: 12.75, max: 30)
#
# Run: 33, exploration: 0.1580861105294992, score: 11
# Scores: (min: 9, avg: 12.696969696969697, max: 30)
#
# Run: 34, exploration: 0.15111286553822956, score: 10
# Scores: (min: 9, avg: 12.617647058823529, max: 30)
#
# Run: 35, exploration: 0.14372497725712216, score: 11
# Scores: (min: 9, avg: 12.571428571428571, max: 30)
#
# Run: 36, exploration: 0.13807558583895513, score: 9
# Scores: (min: 9, avg: 12.472222222222221, max: 30)
#
# Run: 37, exploration: 0.13066846301911936, score: 12
# Scores: (min: 9, avg: 12.45945945945946, max: 30)
#
# Run: 38, exploration: 0.12490462201997637, score: 10
# Scores: (min: 9, avg: 12.394736842105264, max: 30)
#
# Run: 39, exploration: 0.12059799144222175, score: 8
# Scores: (min: 8, avg: 12.282051282051283, max: 30)
#
# Run: 40, exploration: 0.11585765144771248, score: 9
# Scores: (min: 8, avg: 12.2, max: 30)
#
# Run: 41, exploration: 0.11186295456362313, score: 8
# Scores: (min: 8, avg: 12.097560975609756, max: 30)
#
# Run: 42, exploration: 0.10746596228306791, score: 9
# Scores: (min: 8, avg: 12.023809523809524, max: 30)
#
# Run: 43, exploration: 0.1032418023864836, score: 9
# Scores: (min: 8, avg: 11.953488372093023, max: 30)
#
# Run: 44, exploration: 0.09918368135888474, score: 9
# Scores: (min: 8, avg: 11.886363636363637, max: 30)
#
# Run: 45, exploration: 0.09528507271768329, score: 9
# Scores: (min: 8, avg: 11.822222222222223, max: 30)
#
# Run: 46, exploration: 0.09153970651645797, score: 9
# Scores: (min: 8, avg: 11.76086956521739, max: 30)
#
# Run: 47, exploration: 0.08794155926129824, score: 9
# Scores: (min: 8, avg: 11.702127659574469, max: 30)
#
# Run: 48, exploration: 0.08448484422350626, score: 9
# Scores: (min: 8, avg: 11.645833333333334, max: 30)
#
# Run: 49, exploration: 0.08035439121179945, score: 11
# Scores: (min: 8, avg: 11.63265306122449, max: 30)
#
# Run: 50, exploration: 0.07758382377679894, score: 8
# Scores: (min: 8, avg: 11.56, max: 30)
#
# Run: 51, exploration: 0.0745342397963533, score: 9
# Scores: (min: 8, avg: 11.509803921568627, max: 30)
#
# Run: 52, exploration: 0.0712465030521374, score: 10
# Scores: (min: 8, avg: 11.48076923076923, max: 30)
#
# Run: 53, exploration: 0.06844601986126451, score: 9
# Scores: (min: 8, avg: 11.433962264150944, max: 30)
#
# Run: 54, exploration: 0.06575561514114299, score: 9
# Scores: (min: 8, avg: 11.38888888888889, max: 30)
#
# Run: 55, exploration: 0.06129936495526111, score: 15
# Scores: (min: 8, avg: 11.454545454545455, max: 30)
#
# Run: 56, exploration: 0.05830244700006734, score: 11
# Scores: (min: 8, avg: 11.446428571428571, max: 30)
#
# Run: 57, exploration: 0.05462441922520914, score: 14
# Scores: (min: 8, avg: 11.491228070175438, max: 30)
#
# Run: 58, exploration: 0.05066791621302729, score: 16
# Scores: (min: 8, avg: 11.568965517241379, max: 30)
#
# Run: 59, exploration: 0.04794981455780219, score: 12
# Scores: (min: 8, avg: 11.576271186440678, max: 30)
#
# Run: 60, exploration: 0.04537752660798141, score: 12
# Scores: (min: 8, avg: 11.583333333333334, max: 30)
#
# Run: 61, exploration: 0.04230229704853423, score: 15
# Scores: (min: 8, avg: 11.639344262295081, max: 30)
#
# Run: 62, exploration: 0.039435475429100995, score: 15
# Scores: (min: 8, avg: 11.693548387096774, max: 30)
#
# Run: 63, exploration: 0.03694767635022522, score: 14
# Scores: (min: 8, avg: 11.73015873015873, max: 30)
#
# Run: 64, exploration: 0.03514130927386981, score: 11
# Scores: (min: 8, avg: 11.71875, max: 30)
#
# Run: 65, exploration: 0.03325613897196732, score: 12
# Scores: (min: 8, avg: 11.723076923076922, max: 30)
#
# Run: 66, exploration: 0.03131473892591842, score: 13
# Scores: (min: 8, avg: 11.742424242424242, max: 30)
#
# Run: 67, exploration: 0.029783765425331846, score: 11
# Scores: (min: 8, avg: 11.73134328358209, max: 30)
#
# Run: 68, exploration: 0.02832764101944931, score: 11
# Scores: (min: 8, avg: 11.720588235294118, max: 30)
#
# Run: 69, exploration: 0.026407880170317945, score: 15
# Scores: (min: 8, avg: 11.768115942028986, max: 30)
#
# Run: 70, exploration: 0.02524301744132218, score: 10
# Scores: (min: 8, avg: 11.742857142857142, max: 30)
#
# Run: 71, exploration: 0.023769400938086327, score: 13
# Scores: (min: 8, avg: 11.76056338028169, max: 30)
#
# Run: 72, exploration: 0.022047758717570132, score: 16
# Scores: (min: 8, avg: 11.819444444444445, max: 30)
#
# Run: 73, exploration: 0.020450816818411825, score: 16
# Scores: (min: 8, avg: 11.876712328767123, max: 30)
#
# Run: 74, exploration: 0.019064867404770626, score: 15
# Scores: (min: 8, avg: 11.91891891891892, max: 30)
#
# Run: 75, exploration: 0.017951913959130504, score: 13
# Scores: (min: 8, avg: 11.933333333333334, max: 30)
#
# Run: 76, exploration: 0.017160047465104442, score: 10
# Scores: (min: 8, avg: 11.907894736842104, max: 30)
#
# Run: 77, exploration: 0.01607750060057119, score: 14
# Scores: (min: 8, avg: 11.935064935064934, max: 30)
#
# Run: 78, exploration: 0.014912990653247866, score: 16
# Scores: (min: 8, avg: 11.987179487179487, max: 30)
#
# Run: 79, exploration: 0.014042412118399107, score: 13
# Scores: (min: 8, avg: 12, max: 30)
#
# Run: 80, exploration: 0.013222655514775413, score: 13
# Scores: (min: 8, avg: 12.0125, max: 30)
#
# Run: 81, exploration: 0.012513320603703188, score: 12
# Scores: (min: 8, avg: 12.012345679012345, max: 30)
#
# Run: 82, exploration: 0.01184203826198843, score: 12
# Scores: (min: 8, avg: 12.012195121951219, max: 30)
# Run: 83, exploration: 0.011150733307840981, score: 13
# Scores: (min: 8, avg: 12.024096385542169, max: 30)
#
# Run: 84, exploration: 0.010552547534153616, score: 12
# Scores: (min: 8, avg: 12.023809523809524, max: 30)
#
# Run: 85, exploration: 0.010137759008060509, score: 9
# Scores: (min: 8, avg: 11.988235294117647, max: 30)
#
# Run: 86, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12, max: 30)
#
# Run: 87, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.988505747126437, max: 30)
#
# Run: 88, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.988636363636363, max: 30)
#
# Run: 89, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.97752808988764, max: 30)
#
# Run: 90, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.988888888888889, max: 30)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.967032967032967, max: 30)
#
# Run: 92, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.978260869565217, max: 30)
#
# Run: 93, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.010752688172044, max: 30)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.98936170212766, max: 30)
#
# Run: 95, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.989473684210527, max: 30)
#
# Run: 96, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.979166666666666, max: 30)
#
# Run: 97, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12, max: 30)
#
# Run: 98, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.03061224489796, max: 30)
#
# Run: 99, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.02020202020202, max: 30)
#
# Run: 100, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.01, max: 30)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.98, max: 30)
#
# Run: 102, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.92, max: 30)
#
# Run: 103, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.94, max: 30)
#
# Run: 104, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.89, max: 30)
#
# Run: 105, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.82, max: 30)
#
# Run: 106, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.87, max: 30)
#
# Run: 107, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.89, max: 30)
#
# Run: 108, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.96, max: 30)
#
# Run: 109, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.77, max: 17)
#
# Run: 110, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.81, max: 17)
#
# Run: 111, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.84, max: 17)
#
# Run: 112, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.88, max: 17)
#
# Run: 113, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.88, max: 17)
#
# Run: 114, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.88, max: 17)
#
# Run: 115, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.92, max: 17)
#
# Run: 116, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.96, max: 17)
#
# Run: 117, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.98, max: 17)
#
# Run: 118, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.05, max: 17)
#
# Run: 119, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 12.13, max: 20)
#
# Run: 120, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.19, max: 20)
#
# Run: 121, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 12.22, max: 20)
#
# Run: 122, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.25, max: 20)
#
# Run: 123, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.29, max: 20)
#
# Run: 124, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.4, max: 23)
#
# Run: 125, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.43, max: 23)
#
# Run: 126, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.52, max: 23)
#
# Run: 127, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.62, max: 23)
#
# Run: 128, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 12.69, max: 23)
#
# Run: 129, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.74, max: 23)
#
# Run: 130, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.87, max: 24)
#
# Run: 131, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 13.06, max: 29)
#
# Run: 132, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.15, max: 29)
#
# Run: 133, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 13.4, max: 36)
#
# Run: 134, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 13.56, max: 36)
#
# Run: 135, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 13.65, max: 36)
#
# Run: 136, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.83, max: 36)
#
# Run: 137, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 14.11, max: 40)
#
# Run: 138, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 14.35, max: 40)
#
# Run: 139, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 14.5, max: 40)
#
# Run: 140, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.67, max: 40)
#
# Run: 141, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 14.97, max: 40)
#
# Run: 142, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 15.25, max: 40)
#
# Run: 143, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 15.66, max: 50)
#
# Run: 144, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 16.08, max: 51)
#
# Run: 145, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 16.49, max: 51)
#
# Run: 146, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 16.83, max: 51)
#
# Run: 147, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 17.56, max: 82)
#
# Run: 148, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 17.98, max: 82)
#
# Run: 149, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 18.86, max: 99)
#
# Run: 150, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 19.15, max: 99)
#
# Run: 151, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 19.51, max: 99)
#
# Run: 152, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 19.69, max: 99)
#
# Run: 153, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 19.84, max: 99)
#
# Run: 154, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 20.56, max: 99)
#
# Run: 155, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 21.01, max: 99)
#
# Run: 156, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 21.33, max: 99)
#
# Run: 157, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 22.47, max: 128)
#
# Run: 158, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 22.95, max: 128)
#
# Run: 159, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 24.12, max: 129)
#
# Run: 160, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 24.89, max: 129)
#
# Run: 161, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 25.05, max: 129)
#
# Run: 162, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 25.55, max: 129)
#
# Run: 163, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 26.23, max: 129)
#
# Run: 164, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 26.55, max: 129)
#
# Run: 165, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 26.76, max: 129)
#
# Run: 166, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 27.06, max: 129)
#
# Run: 167, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 27.49, max: 129)
#
# Run: 168, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 27.85, max: 129)
#
# Run: 169, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 28.71, max: 129)
#
# Run: 170, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 29.51, max: 129)
#
# Run: 171, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 29.81, max: 129)
#
# Run: 172, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 30.33, max: 129)
#
# Run: 173, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 31.1, max: 129)
#
# Run: 174, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 31.78, max: 129)
#
# Run: 175, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 32.23, max: 129)
#
# Run: 176, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 32.68, max: 129)
#
# Run: 177, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 33.13, max: 129)
#
# Run: 178, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 33.47, max: 129)
#
# Run: 179, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 33.84, max: 129)
#
# Run: 180, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 35.1, max: 139)
#
# Run: 181, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 36.03, max: 139)
#
# Run: 182, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 37.09, max: 139)
#
# Run: 183, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 37.71, max: 139)
#
# Run: 184, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 38.58, max: 139)
# Run: 185, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 39.42, max: 139)
#
# Run: 186, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 39.87, max: 139)
#
# Run: 187, exploration: 0.01, score: 78
# Scores: (min: 10, avg: 40.54, max: 139)
#
# Run: 188, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 41.75, max: 139)
#
# Run: 189, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 42.66, max: 139)
#
# Run: 190, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 43.7, max: 139)
#
# Run: 191, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 44.59, max: 139)
#
# Run: 192, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 45.27, max: 139)
#
# Run: 193, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 46.15, max: 139)
#
# Run: 194, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 46.74, max: 139)
#
# Run: 195, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 47.69, max: 139)
#
# Run: 196, exploration: 0.01, score: 87
# Scores: (min: 11, avg: 48.45, max: 139)
#
# Run: 197, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 49.31, max: 139)
#
# Run: 198, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 50.39, max: 139)
#
# Run: 199, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 51.22, max: 139)
#
# Run: 200, exploration: 0.01, score: 83
# Scores: (min: 11, avg: 51.94, max: 139)
#
# Run: 201, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 52.71, max: 139)
#
# Run: 202, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 54.1, max: 151)
#
# Run: 203, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 54.85, max: 151)
#
# Run: 204, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 55.99, max: 151)
#
# Run: 205, exploration: 0.01, score: 79
# Scores: (min: 11, avg: 56.66, max: 151)
#
# Run: 206, exploration: 0.01, score: 92
# Scores: (min: 11, avg: 57.42, max: 151)
#
# Run: 207, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 58.44, max: 151)
#
# Run: 208, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 59.7, max: 151)
#
# Run: 209, exploration: 0.01, score: 158
# Scores: (min: 13, avg: 61.17, max: 158)
#
# Run: 210, exploration: 0.01, score: 149
# Scores: (min: 13, avg: 62.5, max: 158)
#
# Run: 211, exploration: 0.01, score: 89
# Scores: (min: 13, avg: 63.25, max: 158)
#
# Run: 212, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 64.48, max: 158)
#
# Run: 213, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 65.71, max: 158)
#
# Run: 214, exploration: 0.01, score: 128
# Scores: (min: 13, avg: 66.84, max: 158)
#
# Run: 215, exploration: 0.01, score: 200
# Scores: (min: 13, avg: 68.7, max: 200)
#
# Run: 216, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 70.23, max: 200)
#
# Run: 217, exploration: 0.01, score: 140
# Scores: (min: 13, avg: 71.48, max: 200)
#
# Run: 218, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 72.63, max: 200)
#
# Run: 219, exploration: 0.01, score: 243
# Scores: (min: 13, avg: 74.86, max: 243)
#
# Run: 220, exploration: 0.01, score: 118
# Scores: (min: 13, avg: 75.88, max: 243)
#
# Run: 221, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 78.07, max: 243)
#
# Run: 222, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 79.49, max: 243)
#
# Run: 223, exploration: 0.01, score: 161
# Scores: (min: 15, avg: 80.96, max: 243)
#
# Run: 224, exploration: 0.01, score: 158
# Scores: (min: 15, avg: 82.31, max: 243)
#
# Run: 225, exploration: 0.01, score: 176
# Scores: (min: 16, avg: 83.92, max: 243)
#
# Run: 226, exploration: 0.01, score: 162
# Scores: (min: 16, avg: 85.35, max: 243)
#
# Run: 227, exploration: 0.01, score: 231
# Scores: (min: 16, avg: 87.44, max: 243)
#
# Run: 228, exploration: 0.01, score: 156
# Scores: (min: 17, avg: 88.84, max: 243)
#
# Run: 229, exploration: 0.01, score: 189
# Scores: (min: 20, avg: 90.56, max: 243)
#
# Run: 230, exploration: 0.01, score: 183
# Scores: (min: 20, avg: 92.15, max: 243)
#
# Run: 231, exploration: 0.01, score: 181
# Scores: (min: 20, avg: 93.67, max: 243)
#
# Run: 232, exploration: 0.01, score: 199
# Scores: (min: 20, avg: 95.44, max: 243)
#
# Run: 233, exploration: 0.01, score: 164
# Scores: (min: 20, avg: 96.72, max: 243)
#
# Run: 234, exploration: 0.01, score: 247
# Scores: (min: 20, avg: 98.93, max: 247)
#
# Run: 235, exploration: 0.01, score: 188
# Scores: (min: 23, avg: 100.61, max: 247)
#
# Run: 236, exploration: 0.01, score: 204
# Scores: (min: 23, avg: 102.38, max: 247)
#
# Run: 237, exploration: 0.01, score: 256
# Scores: (min: 23, avg: 104.54, max: 256)
#
# Run: 238, exploration: 0.01, score: 202
# Scores: (min: 23, avg: 106.22, max: 256)
#
# Run: 239, exploration: 0.01, score: 164
# Scores: (min: 24, avg: 107.63, max: 256)
#
# Run: 240, exploration: 0.01, score: 274
# Scores: (min: 24, avg: 110.11, max: 274)
#
# Run: 241, exploration: 0.01, score: 320
# Scores: (min: 24, avg: 112.93, max: 320)
#
# Run: 242, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 117.56, max: 500)
#
# Run: 243, exploration: 0.01, score: 257
# Scores: (min: 24, avg: 119.63, max: 500)
#
# Run: 244, exploration: 0.01, score: 230
# Scores: (min: 24, avg: 121.42, max: 500)
#
# Run: 245, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 125.92, max: 500)
#
# Run: 246, exploration: 0.01, score: 219
# Scores: (min: 24, avg: 127.68, max: 500)
#
# Run: 247, exploration: 0.01, score: 225
# Scores: (min: 24, avg: 129.11, max: 500)
#
# Run: 248, exploration: 0.01, score: 224
# Scores: (min: 24, avg: 130.84, max: 500)
#
# Run: 249, exploration: 0.01, score: 229
# Scores: (min: 24, avg: 132.14, max: 500)
#
# Run: 250, exploration: 0.01, score: 191
# Scores: (min: 24, avg: 133.68, max: 500)
#
# Run: 251, exploration: 0.01, score: 187
# Scores: (min: 24, avg: 135.1, max: 500)
#
# Run: 252, exploration: 0.01, score: 409
# Scores: (min: 24, avg: 138.91, max: 500)
#
# Run: 253, exploration: 0.01, score: 255
# Scores: (min: 31, avg: 141.22, max: 500)
#
# Run: 254, exploration: 0.01, score: 208
# Scores: (min: 31, avg: 142.49, max: 500)
#
# Run: 255, exploration: 0.01, score: 277
# Scores: (min: 31, avg: 144.66, max: 500)
#
# Run: 256, exploration: 0.01, score: 197
# Scores: (min: 31, avg: 146.2, max: 500)
#
# Run: 257, exploration: 0.01, score: 416
# Scores: (min: 31, avg: 149.08, max: 500)
#
# Run: 258, exploration: 0.01, score: 200
# Scores: (min: 31, avg: 150.44, max: 500)
#
# Run: 259, exploration: 0.01, score: 352
# Scores: (min: 31, avg: 152.67, max: 500)
#
# Run: 260, exploration: 0.01, score: 163
# Scores: (min: 31, avg: 153.41, max: 500)
#
# Run: 261, exploration: 0.01, score: 182
# Scores: (min: 33, avg: 154.92, max: 500)
#
# Run: 262, exploration: 0.01, score: 174
# Scores: (min: 33, avg: 156.01, max: 500)
#
# Run: 263, exploration: 0.01, score: 174
# Scores: (min: 33, avg: 156.93, max: 500)
#
# Run: 264, exploration: 0.01, score: 198
# Scores: (min: 33, avg: 158.48, max: 500)
#
# Run: 265, exploration: 0.01, score: 143
# Scores: (min: 43, avg: 159.58, max: 500)
#
# Run: 266, exploration: 0.01, score: 176
# Scores: (min: 43, avg: 160.91, max: 500)
#
# Run: 267, exploration: 0.01, score: 155
# Scores: (min: 43, avg: 161.92, max: 500)
#
# Run: 268, exploration: 0.01, score: 245
# Scores: (min: 43, avg: 163.9, max: 500)
#
# Run: 269, exploration: 0.01, score: 253
# Scores: (min: 43, avg: 165.42, max: 500)
#
# Run: 270, exploration: 0.01, score: 291
# Scores: (min: 43, avg: 167.43, max: 500)
#
# Run: 271, exploration: 0.01, score: 260
# Scores: (min: 50, avg: 169.6, max: 500)
#
# Run: 272, exploration: 0.01, score: 231
# Scores: (min: 50, avg: 171.23, max: 500)
#
# Run: 273, exploration: 0.01, score: 178
# Scores: (min: 50, avg: 172.08, max: 500)
#
# Run: 274, exploration: 0.01, score: 190
# Scores: (min: 50, avg: 173.15, max: 500)
#
# Run: 275, exploration: 0.01, score: 239
# Scores: (min: 50, avg: 174.96, max: 500)
#
# Run: 276, exploration: 0.01, score: 190
# Scores: (min: 50, avg: 176.31, max: 500)
#
# Run: 277, exploration: 0.01, score: 218
# Scores: (min: 50, avg: 177.9, max: 500)
#
# Run: 278, exploration: 0.01, score: 207
# Scores: (min: 50, avg: 179.47, max: 500)
#
# Run: 279, exploration: 0.01, score: 203
# Scores: (min: 58, avg: 181, max: 500)
#
# Run: 280, exploration: 0.01, score: 185
# Scores: (min: 58, avg: 181.46, max: 500)
#
# Run: 281, exploration: 0.01, score: 228
# Scores: (min: 58, avg: 182.69, max: 500)
#
# Run: 282, exploration: 0.01, score: 176
# Scores: (min: 58, avg: 183.27, max: 500)
#
# Run: 283, exploration: 0.01, score: 224
# Scores: (min: 58, avg: 184.76, max: 500)
#
# Run: 284, exploration: 0.01, score: 168
# Scores: (min: 58, avg: 185.45, max: 500)
#
# Run: 285, exploration: 0.01, score: 295
# Scores: (min: 58, avg: 187.47, max: 500)
# Run: 286, exploration: 0.01, score: 301
# Scores: (min: 69, avg: 189.9, max: 500)
#
# Run: 287, exploration: 0.01, score: 174
# Scores: (min: 69, avg: 190.86, max: 500)
#
# Run: 288, exploration: 0.01, score: 144
# Scores: (min: 69, avg: 190.97, max: 500)
#
# Run: 289, exploration: 0.01, score: 176
# Scores: (min: 69, avg: 191.71, max: 500)
#
# Run: 290, exploration: 0.01, score: 215
# Scores: (min: 69, avg: 192.69, max: 500)
#
# Run: 291, exploration: 0.01, score: 233
# Scores: (min: 69, avg: 194.03, max: 500)
#
# Run: 292, exploration: 0.01, score: 196
# Scores: (min: 69, avg: 195.18, max: 500)
#
# Solved in 192 runs, 292 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-9e1f68e2b6f8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.01  #change the learning rate to larger value
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.9558895783575597, score: 19
# Scores: (min: 10, avg: 14.5, max: 19)
#
# Run: 3, exploration: 0.9000874278732445, score: 13
# Scores: (min: 10, avg: 14, max: 19)
#
# Run: 4, exploration: 0.8433051360508336, score: 14
# Scores: (min: 10, avg: 14, max: 19)
#
# Run: 5, exploration: 0.7552531090661897, score: 23
# Scores: (min: 10, avg: 15.8, max: 23)
#
# Run: 6, exploration: 0.5878229785513479, score: 51
# Scores: (min: 10, avg: 21.666666666666668, max: 51)
#
# Run: 7, exploration: 0.5647174463480732, score: 9
# Scores: (min: 9, avg: 19.857142857142858, max: 51)
#
# Run: 8, exploration: 0.5425201222922789, score: 9
# Scores: (min: 9, avg: 18.5, max: 51)
#
# Run: 9, exploration: 0.5057535983897912, score: 15
# Scores: (min: 9, avg: 18.11111111111111, max: 51)
#
# Run: 10, exploration: 0.47862223409330756, score: 12
# Scores: (min: 9, avg: 17.5, max: 51)
#
# Run: 11, exploration: 0.4439551321314536, score: 16
# Scores: (min: 9, avg: 17.363636363636363, max: 51)
#
# Run: 12, exploration: 0.42437208406280985, score: 10
# Scores: (min: 9, avg: 16.75, max: 51)
#
# Run: 13, exploration: 0.4036245882390106, score: 11
# Scores: (min: 9, avg: 16.307692307692307, max: 51)
#
# Run: 14, exploration: 0.3858205374665315, score: 10
# Scores: (min: 9, avg: 15.857142857142858, max: 51)
#
# Run: 15, exploration: 0.36880183088056995, score: 10
# Scores: (min: 9, avg: 15.466666666666667, max: 51)
#
# Run: 16, exploration: 0.3455358541129786, score: 14
# Scores: (min: 9, avg: 15.375, max: 51)
#
# Run: 17, exploration: 0.33195389135223546, score: 9
# Scores: (min: 9, avg: 15, max: 51)
#
# Run: 18, exploration: 0.3173112652388396, score: 10
# Scores: (min: 9, avg: 14.722222222222221, max: 51)
#
# Run: 19, exploration: 0.3033145315372582, score: 10
# Scores: (min: 9, avg: 14.473684210526315, max: 51)
#
# Run: 20, exploration: 0.2913921604631864, score: 9
# Scores: (min: 9, avg: 14.2, max: 51)
#
# Run: 21, exploration: 0.27853872940185365, score: 10
# Scores: (min: 9, avg: 14, max: 51)
#
# Run: 22, exploration: 0.2662522686041882, score: 10
# Scores: (min: 9, avg: 13.818181818181818, max: 51)
#
# Run: 23, exploration: 0.2532352299289372, score: 11
# Scores: (min: 9, avg: 13.695652173913043, max: 51)
#
# Run: 24, exploration: 0.2384520680152932, score: 13
# Scores: (min: 9, avg: 13.666666666666666, max: 51)
#
# Run: 25, exploration: 0.2290792429684691, score: 9
# Scores: (min: 9, avg: 13.48, max: 51)
#
# Run: 26, exploration: 0.21355457002808648, score: 15
# Scores: (min: 9, avg: 13.538461538461538, max: 51)
#
# Run: 27, exploration: 0.2041345879004775, score: 10
# Scores: (min: 9, avg: 13.407407407407407, max: 51)
#
# Run: 28, exploration: 0.19318370215794672, score: 12
# Scores: (min: 9, avg: 13.357142857142858, max: 51)
#
# Run: 29, exploration: 0.18373897616330553, score: 11
# Scores: (min: 9, avg: 13.275862068965518, max: 51)
#
# Run: 30, exploration: 0.17043057265153258, score: 16
# Scores: (min: 9, avg: 13.366666666666667, max: 51)
#
# Run: 31, exploration: 0.16291280823111093, score: 10
# Scores: (min: 9, avg: 13.258064516129032, max: 51)
#
# Run: 32, exploration: 0.1572956799768517, score: 8
# Scores: (min: 8, avg: 13.09375, max: 51)
#
# Run: 33, exploration: 0.15035730121053842, score: 10
# Scores: (min: 8, avg: 13, max: 51)
#
# Run: 34, exploration: 0.11820406108847166, score: 49
# Scores: (min: 8, avg: 14.058823529411764, max: 51)
#
# Run: 35, exploration: 0.09576389217857617, score: 43
# Scores: (min: 8, avg: 14.885714285714286, max: 51)
#
# Run: 36, exploration: 0.07196434741762824, score: 58
# Scores: (min: 8, avg: 16.083333333333332, max: 58)
#
# Run: 37, exploration: 0.06317096204211972, score: 27
# Scores: (min: 8, avg: 16.37837837837838, max: 58)
#
# Run: 38, exploration: 0.046997986793891174, score: 60
# Scores: (min: 8, avg: 17.526315789473685, max: 60)
#
# Run: 39, exploration: 0.041670929977297724, score: 25
# Scores: (min: 8, avg: 17.71794871794872, max: 60)
#
# Run: 40, exploration: 0.03769595998025326, score: 21
# Scores: (min: 8, avg: 17.8, max: 60)
#
# Run: 41, exploration: 0.03621424652392737, score: 9
# Scores: (min: 8, avg: 17.585365853658537, max: 60)
#
# Run: 42, exploration: 0.03479077471386296, score: 9
# Scores: (min: 8, avg: 17.38095238095238, max: 60)
#
# Run: 43, exploration: 0.033423255248208356, score: 9
# Scores: (min: 8, avg: 17.186046511627907, max: 60)
#
# Run: 44, exploration: 0.03163025067641567, score: 12
# Scores: (min: 8, avg: 17.068181818181817, max: 60)
#
# Run: 45, exploration: 0.03038696179137978, score: 9
# Scores: (min: 8, avg: 16.88888888888889, max: 60)
#
# Run: 46, exploration: 0.029339239003388088, score: 8
# Scores: (min: 8, avg: 16.695652173913043, max: 60)
#
# Run: 47, exploration: 0.028186002814352063, score: 9
# Scores: (min: 8, avg: 16.53191489361702, max: 60)
#
# Run: 48, exploration: 0.02707809682994571, score: 9
# Scores: (min: 8, avg: 16.375, max: 60)
#
# Run: 49, exploration: 0.024991218342344988, score: 17
# Scores: (min: 8, avg: 16.387755102040817, max: 60)
#
# Run: 50, exploration: 0.024129537298457977, score: 8
# Scores: (min: 8, avg: 16.22, max: 60)
#
# Run: 51, exploration: 0.02171869316274056, score: 22
# Scores: (min: 8, avg: 16.333333333333332, max: 60)
#
# Run: 52, exploration: 0.01724627885940145, score: 47
# Scores: (min: 8, avg: 16.923076923076923, max: 60)
#
# Run: 53, exploration: 0.016485538227150154, score: 10
# Scores: (min: 8, avg: 16.79245283018868, max: 60)
#
# Run: 54, exploration: 0.014838425699981627, score: 22
# Scores: (min: 8, avg: 16.88888888888889, max: 60)
#
# Run: 55, exploration: 0.01190154599194817, score: 45
# Scores: (min: 8, avg: 17.4, max: 60)
#
# Run: 56, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 18.321428571428573, max: 69)
#
# Run: 57, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.140350877192983, max: 69)
#
# Run: 58, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.46551724137931, max: 69)
#
# Run: 59, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.322033898305083, max: 69)
#
# Run: 60, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.45, max: 69)
#
# Run: 61, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.868852459016395, max: 69)
#
# Run: 62, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.725806451612904, max: 69)
#
# Run: 63, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.761904761904763, max: 69)
#
# Run: 64, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.75, max: 69)
#
# Run: 65, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.76923076923077, max: 69)
#
# Run: 66, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.78787878787879, max: 69)
#
# Run: 67, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.880597014925375, max: 69)
#
# Run: 68, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 19.294117647058822, max: 69)
#
# Run: 69, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.246376811594203, max: 69)
#
# Run: 70, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 19.5, max: 69)
#
# Run: 71, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.56338028169014, max: 69)
#
# Run: 72, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.5, max: 69)
#
# Run: 73, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 19.767123287671232, max: 69)
#
# Run: 74, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 20.68918918918919, max: 88)
#
# Run: 75, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.546666666666667, max: 88)
#
# Run: 76, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 20.55263157894737, max: 88)
#
# Run: 77, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 20.714285714285715, max: 88)
#
# Run: 78, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 20.846153846153847, max: 88)
#
# Run: 79, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 21.49367088607595, max: 88)
#
# Run: 80, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 21.4375, max: 88)
#
# Run: 81, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.28395061728395, max: 88)
#
# Run: 82, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 21.365853658536587, max: 88)
#
# Run: 83, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 21.662650602409638, max: 88)
#
# Run: 84, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 21.63095238095238, max: 88)
#
# Run: 85, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 21.8, max: 88)
#
# Run: 86, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.825581395348838, max: 88)
#
# Run: 87, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.908045977011493, max: 88)
# Run: 88, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 22.295454545454547, max: 88)
#
# Run: 89, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 23.01123595505618, max: 88)
#
# Run: 90, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.033333333333335, max: 88)
#
# Run: 91, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 23.23076923076923, max: 88)
#
# Run: 92, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.08695652173913, max: 88)
#
# Run: 93, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 23.225806451612904, max: 88)
#
# Run: 94, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.19148936170213, max: 88)
#
# Run: 95, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.210526315789473, max: 88)
#
# Run: 96, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.177083333333332, max: 88)
#
# Run: 97, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 23.391752577319586, max: 88)
#
# Run: 98, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.46938775510204, max: 88)
#
# Run: 99, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 23.838383838383837, max: 88)
#
# Run: 100, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.74, max: 88)
#
# Run: 101, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 24.11, max: 88)
#
# Run: 102, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 24.43, max: 88)
#
# Run: 103, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 24.84, max: 88)
#
# Run: 104, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 24.94, max: 88)
#
# Run: 105, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 25.03, max: 88)
#
# Run: 106, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 24.76, max: 88)
#
# Run: 107, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 25.29, max: 88)
#
# Run: 108, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.34, max: 88)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.29, max: 88)
#
# Run: 110, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 25.89, max: 88)
#
# Run: 111, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 26.01, max: 88)
#
# Run: 112, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 26.39, max: 88)
#
# Run: 113, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 27.01, max: 88)
#
# Run: 114, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 27.56, max: 88)
#
# Run: 115, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 27.87, max: 88)
#
# Run: 116, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 28.11, max: 88)
#
# Run: 117, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 28.63, max: 88)
#
# Run: 118, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 28.95, max: 88)
#
# Run: 119, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 29.27, max: 88)
#
# Run: 120, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 29.4, max: 88)
#
# Run: 121, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 29.89, max: 88)
#
# Run: 122, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 30.49, max: 88)
#
# Run: 123, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 30.87, max: 88)
#
# Run: 124, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 31.05, max: 88)
#
# Run: 125, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.07, max: 88)
#
# Run: 126, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 31.24, max: 88)
#
# Run: 127, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 31.31, max: 88)
#
# Run: 128, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 31.44, max: 88)
#
# Run: 129, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 31.47, max: 88)
#
# Run: 130, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 31.63, max: 88)
#
# Run: 131, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 31.67, max: 88)
#
# Run: 132, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 31.75, max: 88)
#
# Run: 133, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 31.86, max: 88)
#
# Run: 134, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 31.58, max: 88)
#
# Run: 135, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 31.38, max: 88)
#
# Run: 136, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.95, max: 88)
#
# Run: 137, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 30.93, max: 88)
#
# Run: 138, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 30.5, max: 88)
#
# Run: 139, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 30.42, max: 88)
#
# Run: 140, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 30.46, max: 88)
#
# Run: 141, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.49, max: 88)
#
# Run: 142, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 30.84, max: 88)
#
# Run: 143, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 30.95, max: 88)
#
# Run: 144, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 31.04, max: 88)
#
# Run: 145, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 31.25, max: 88)
#
# Run: 146, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 31.58, max: 88)
#
# Run: 147, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 31.83, max: 88)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.83, max: 88)
#
# Run: 149, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 31.92, max: 88)
#
# Run: 150, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 32.04, max: 88)
#
# Run: 151, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 32.14, max: 88)
#
# Run: 152, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 32.2, max: 88)
#
# Run: 153, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 32.27, max: 88)
#
# Run: 154, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 32.19, max: 88)
#
# Run: 155, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 32.23, max: 88)
#
# Run: 156, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 31.73, max: 88)
#
# Run: 157, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 32.23, max: 88)
#
# Run: 158, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 32.19, max: 88)
#
# Run: 159, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 32.69, max: 88)
#
# Run: 160, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 33.16, max: 88)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 32.82, max: 88)
#
# Run: 162, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 32.81, max: 88)
#
# Run: 163, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 33.03, max: 88)
#
# Run: 164, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 33.13, max: 88)
#
# Run: 165, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 33.42, max: 88)
#
# Run: 166, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 34.14, max: 92)
#
# Run: 167, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 34.31, max: 92)
#
# Run: 168, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 33.94, max: 92)
#
# Run: 169, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 33.99, max: 92)
#
# Run: 170, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 33.83, max: 92)
#
# Run: 171, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 33.94, max: 92)
#
# Run: 172, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 34.97, max: 118)
#
# Run: 173, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 34.74, max: 118)
#
# Run: 174, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 34.25, max: 118)
#
# Run: 175, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 34.45, max: 118)
#
# Run: 176, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 34.69, max: 118)
#
# Run: 177, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 34.63, max: 118)
#
# Run: 178, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 34.69, max: 118)
#
# Run: 179, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 34.49, max: 118)
#
# Run: 180, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 35, max: 118)
#
# Run: 181, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 35.52, max: 118)
#
# Run: 182, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 35.84, max: 118)
#
# Run: 183, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 35.61, max: 118)
#
# Run: 184, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 36.66, max: 124)
#
# Run: 185, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 36.55, max: 124)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 36.4, max: 124)
#
# Run: 187, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 36.23, max: 124)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 35.77, max: 124)
#
# Run: 189, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 35.01, max: 124)
#
# Run: 190, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 34.85, max: 124)
#
# Run: 191, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 34.52, max: 124)
# Run: 192, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.51, max: 124)
#
# Run: 193, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 35.88, max: 173)
#
# Run: 194, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 35.91, max: 173)
#
# Run: 195, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 35.96, max: 173)
#
# Run: 196, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.85, max: 173)
#
# Run: 197, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 35.71, max: 173)
#
# Run: 198, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 35.65, max: 173)
#
# Run: 199, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 35.25, max: 173)
#
# Run: 200, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 35.24, max: 173)
#
# Run: 201, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 36.24, max: 173)
#
# Run: 202, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 36.47, max: 173)
#
# Run: 203, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 37.59, max: 173)
#
# Run: 204, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 37.48, max: 173)
#
# Run: 205, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 37.61, max: 173)
#
# Run: 206, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 38.24, max: 173)
#
# Run: 207, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 38.03, max: 173)
#
# Run: 208, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 38.26, max: 173)
#
# Run: 209, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 39.68, max: 173)
#
# Run: 210, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 39.81, max: 173)
#
# Run: 211, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 39.66, max: 173)
#
# Run: 212, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 39.41, max: 173)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.78, max: 173)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.22, max: 173)
#
# Run: 215, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.93, max: 173)
#
# Run: 216, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 37.69, max: 173)
#
# Run: 217, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 37.34, max: 173)
#
# Run: 218, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 37.92, max: 173)
#
# Run: 219, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 37.81, max: 173)
#
# Run: 220, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 37.83, max: 173)
#
# Run: 221, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 37.77, max: 173)
#
# Run: 222, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 37.22, max: 173)
#
# Run: 223, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.82, max: 173)
#
# Run: 224, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.61, max: 173)
#
# Run: 225, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 36.64, max: 173)
#
# Run: 226, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 37.47, max: 173)
#
# Run: 227, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 37.57, max: 173)
#
# Run: 228, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 37.55, max: 173)
#
# Run: 229, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 37.68, max: 173)
#
# Run: 230, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 37.47, max: 173)
#
# Run: 231, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.45, max: 173)
#
# Run: 232, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 38.41, max: 173)
#
# Run: 233, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 39.25, max: 173)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.14, max: 173)
#
# Run: 235, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 40.08, max: 173)
#
# Run: 236, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 40.21, max: 173)
#
# Run: 237, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.26, max: 173)
#
# Run: 238, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 40.4, max: 173)
#
# Run: 239, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 41.05, max: 173)
#
# Run: 240, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 41.28, max: 173)
#
# Run: 241, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 41.48, max: 173)
#
# Run: 242, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 42.24, max: 173)
#
# Run: 243, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 42.27, max: 173)
#
# Run: 244, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 42.24, max: 173)
#
# Run: 245, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 42.09, max: 173)
#
# Run: 246, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 42, max: 173)
#
# Run: 247, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 41.99, max: 173)
#
# Run: 248, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 42.22, max: 173)
#
# Run: 249, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 43.47, max: 173)
#
# Run: 250, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 43.75, max: 173)
#
# Run: 251, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.52, max: 173)
#
# Run: 252, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43.08, max: 173)
#
# Run: 253, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 43, max: 173)
#
# Run: 254, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.96, max: 173)
#
# Run: 255, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 42.55, max: 173)
#
# Run: 256, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 42.48, max: 173)
#
# Run: 257, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42, max: 173)
#
# Run: 258, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.76, max: 173)
#
# Run: 259, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.26, max: 173)
#
# Run: 260, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.63, max: 173)
#
# Run: 261, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.62, max: 173)
#
# Run: 262, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.63, max: 173)
#
# Run: 263, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.3, max: 173)
#
# Run: 264, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.12, max: 173)
#
# Run: 265, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.72, max: 173)
#
# Run: 266, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.88, max: 173)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.56, max: 173)
#
# Run: 268, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 38.58, max: 173)
#
# Run: 269, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.47, max: 173)
#
# Run: 270, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.35, max: 173)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.09, max: 173)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.01, max: 173)
#
# Run: 273, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.94, max: 173)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.65, max: 173)
#
# Run: 275, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.45, max: 173)
#
# Run: 276, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.1, max: 173)
#
# Run: 277, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.92, max: 173)
#
# Run: 278, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 35.63, max: 173)
#
# Run: 279, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.2, max: 173)
#
# Run: 280, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 34.65, max: 173)
#
# Run: 281, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 34.17, max: 173)
#
# Run: 282, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 33.79, max: 173)
#
# Run: 283, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 33.85, max: 173)
#
# Run: 284, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 32.94, max: 173)
#
# Run: 285, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 33.18, max: 173)
#
# Run: 286, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 33.4, max: 173)
#
# Run: 287, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 33.45, max: 173)
#
# Run: 288, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 33.58, max: 173)
#
# Run: 289, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 33.6, max: 173)
#
# Run: 290, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 33.68, max: 173)
#
# Run: 291, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 33.72, max: 173)
#
# Run: 292, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 33.78, max: 173)
#
# Run: 293, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 32.2, max: 166)
#
# Run: 294, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 32.37, max: 166)
#
# Run: 295, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 32.31, max: 166)
# Run: 296, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 32.75, max: 166)
#
# Run: 297, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 32.64, max: 166)
#
# Run: 298, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 32.58, max: 166)
#
# Run: 299, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.48, max: 166)
#
# Run: 300, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 32.43, max: 166)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.06, max: 166)
#
# Run: 302, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.41, max: 166)
#
# Run: 303, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.85, max: 152)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.82, max: 152)
#
# Run: 305, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.46, max: 152)
#
# Run: 306, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.68, max: 152)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.37, max: 152)
#
# Run: 308, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.09, max: 152)
#
# Run: 309, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.67, max: 151)
#
# Run: 310, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.93, max: 151)
#
# Run: 311, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.91, max: 151)
#
# Run: 312, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 25.2, max: 151)
#
# Run: 313, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.23, max: 151)
#
# Run: 314, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.28, max: 151)
#
# Run: 315, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.38, max: 151)
#
# Run: 316, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 25.44, max: 151)
#
# Run: 317, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 25.39, max: 151)
#
# Run: 318, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.72, max: 151)
#
# Run: 319, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.68, max: 151)
#
# Run: 320, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 24.71, max: 151)
#
# Run: 321, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 24.36, max: 151)
#
# Run: 322, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.37, max: 151)
#
# Run: 323, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 24.46, max: 151)
#
# Run: 324, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.55, max: 151)
#
# Run: 325, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 24.54, max: 151)
#
# Run: 326, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.5, max: 151)
#
# Run: 327, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.4, max: 151)
#
# Run: 328, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.29, max: 151)
#
# Run: 329, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.16, max: 151)
#
# Run: 330, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.16, max: 151)
#
# Run: 331, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.14, max: 151)
#
# Run: 332, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 22.19, max: 151)
#
# Run: 333, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.23, max: 151)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.23, max: 151)
#
# Run: 335, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 20.17, max: 151)
#
# Run: 336, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 20.23, max: 151)
#
# Run: 337, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.05, max: 151)
#
# Run: 338, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.84, max: 151)
#
# Run: 339, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.16, max: 151)
#
# Run: 340, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.9, max: 151)
#
# Run: 341, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.96, max: 151)
#
# Run: 342, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.86, max: 151)
#
# Run: 343, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 17.97, max: 151)
#
# Run: 344, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.2, max: 151)
#
# Run: 345, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.19, max: 151)
#
# Run: 346, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.12, max: 151)
#
# Run: 347, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.94, max: 151)
#
# Run: 348, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.77, max: 151)
#
# Run: 349, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 16.73, max: 53)
#
# Run: 350, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.5, max: 53)
#
# Run: 351, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.62, max: 53)
#
# Run: 352, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 16.99, max: 53)
#
# Run: 353, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.05, max: 53)
#
# Run: 354, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 17.55, max: 60)
#
# Run: 355, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.59, max: 60)
#
# Run: 356, exploration: 0.01, score: 79
# Scores: (min: 8, avg: 18.26, max: 79)
#
# Run: 357, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.27, max: 79)
#
# Run: 358, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.49, max: 79)
#
# Run: 359, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.59, max: 79)
#
# Run: 360, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.76, max: 79)
#
# Run: 361, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.83, max: 79)
#
# Run: 362, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.86, max: 79)
#
# Run: 363, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.88, max: 79)
#
# Run: 364, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.93, max: 79)
#
# Run: 365, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.02, max: 79)
#
# Run: 366, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 20.16, max: 122)
#
# Run: 367, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 20.3, max: 122)
#
# Run: 368, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 20.8, max: 122)
#
# Run: 369, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.8, max: 122)
#
# Run: 370, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 20.96, max: 122)
#
# Run: 371, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 20.99, max: 122)
#
# Run: 372, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 21.59, max: 122)
#
# Run: 373, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.63, max: 122)
#
# Run: 374, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 22.05, max: 122)
#
# Run: 375, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 22.18, max: 122)
#
# Run: 376, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 22.39, max: 122)
#
# Run: 377, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 22.97, max: 122)
#
# Run: 378, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.18, max: 122)
#
# Run: 379, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 23.63, max: 122)
#
# Run: 380, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.61, max: 122)
#
# Run: 381, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 24.08, max: 122)
#
# Run: 382, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.02, max: 122)
#
# Run: 383, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.89, max: 122)
#
# Run: 384, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 24.36, max: 122)
#
# Run: 385, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.98, max: 122)
#
# Run: 386, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.88, max: 122)
#
# Run: 387, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.96, max: 122)
#
# Run: 388, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 23.96, max: 122)
#
# Run: 389, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.96, max: 122)
#
# Run: 390, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 24.04, max: 122)
#
# Run: 391, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.29, max: 122)
#
# Run: 392, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 24.69, max: 122)
#
# Run: 393, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 24.91, max: 122)
#
# Run: 394, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 24.77, max: 122)
#
# Run: 395, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 25.06, max: 122)
#
# Run: 396, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 25.51, max: 122)
#
# Run: 397, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 25.99, max: 122)
#
# Run: 398, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 26.14, max: 122)
#
# Run: 399, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 26.19, max: 122)
#
# Run: 400, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 26.33, max: 122)
# Run: 401, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 27.04, max: 122)
#
# Run: 402, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 27.44, max: 122)
#
# Run: 403, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 28.33, max: 122)
#
# Run: 404, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 28.64, max: 122)
#
# Run: 405, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 28.75, max: 122)
#
# Run: 406, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 28.8, max: 122)
#
# Run: 407, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 29.31, max: 122)
#
# Run: 408, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 29.44, max: 122)
#
# Run: 409, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 30.4, max: 122)
#
# Run: 410, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 30.72, max: 122)
#
# Run: 411, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 30.76, max: 122)
#
# Run: 412, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 30.73, max: 122)
#
# Run: 413, exploration: 0.01, score: 88
# Scores: (min: 9, avg: 31.48, max: 122)
#
# Run: 414, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 32.01, max: 122)
#
# Run: 415, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 31.88, max: 122)
#
# Run: 416, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.78, max: 122)
#
# Run: 417, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.67, max: 122)
#
# Run: 418, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 31.43, max: 122)
#
# Run: 419, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 31.26, max: 122)
#
# Run: 420, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 31.07, max: 122)
#
# Run: 421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.98, max: 122)
#
# Run: 422, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.91, max: 122)
#
# Run: 423, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.83, max: 122)
#
# Run: 424, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.74, max: 122)
#
# Run: 425, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.7, max: 122)
#
# Run: 426, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.7, max: 122)
#
# Run: 427, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.62, max: 122)
#
# Run: 428, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.59, max: 122)
#
# Run: 429, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.54, max: 122)
#
# Run: 430, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.51, max: 122)
#
# Run: 431, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.5, max: 122)
#
# Run: 432, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.42, max: 122)
#
# Run: 433, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.42, max: 122)
#
# Run: 434, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.41, max: 122)
#
# Run: 435, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.39, max: 122)
#
# Run: 436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.15, max: 122)
#
# Run: 437, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.11, max: 122)
#
# Run: 438, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.1, max: 122)
#
# Run: 439, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 30.04, max: 122)
#
# Run: 440, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.92, max: 122)
#
# Run: 441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.64, max: 122)
#
# Run: 442, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.64, max: 122)
#
# Run: 443, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.39, max: 122)
#
# Run: 444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.07, max: 122)
#
# Run: 445, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.03, max: 122)
#
# Run: 446, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.87, max: 122)
#
# Run: 447, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.82, max: 122)
#
# Run: 448, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.77, max: 122)
#
# Run: 449, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.39, max: 122)
#
# Run: 450, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.23, max: 122)
#
# Run: 451, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.1, max: 122)
#
# Run: 452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.74, max: 122)
#
# Run: 453, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.68, max: 122)
#
# Run: 454, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.17, max: 122)
#
# Run: 455, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.15, max: 122)
#
# Run: 456, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 26.46, max: 122)
#
# Run: 457, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.44, max: 122)
#
# Run: 458, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.22, max: 122)
#
# Run: 459, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.11, max: 122)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.94, max: 122)
#
# Run: 461, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.88, max: 122)
#
# Run: 462, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.84, max: 122)
#
# Run: 463, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.82, max: 122)
#
# Run: 464, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 25.77, max: 122)
#
# Run: 465, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.68, max: 122)
#
# Run: 466, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.56, max: 106)
#
# Run: 467, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.41, max: 106)
#
# Run: 468, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 23.87, max: 106)
#
# Run: 469, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.86, max: 106)
#
# Run: 470, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.71, max: 106)
#
# Run: 471, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.69, max: 106)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.09, max: 106)
#
# Run: 473, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.06, max: 106)
#
# Run: 474, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.62, max: 106)
#
# Run: 475, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.48, max: 106)
#
# Run: 476, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.26, max: 106)
#
# Run: 477, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.68, max: 106)
#
# Run: 478, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 21.5, max: 106)
#
# Run: 479, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.05, max: 106)
#
# Run: 480, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.04, max: 106)
#
# Run: 481, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.54, max: 106)
#
# Run: 482, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.46, max: 106)
#
# Run: 483, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.4, max: 106)
#
# Run: 484, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.7, max: 106)
#
# Run: 485, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.69, max: 106)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.58, max: 106)
#
# Run: 487, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.42, max: 106)
#
# Run: 488, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.31, max: 106)
#
# Run: 489, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.3, max: 106)
#
# Run: 490, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.18, max: 106)
#
# Run: 491, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.98, max: 106)
#
# Run: 492, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.61, max: 106)
#
# Run: 493, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.65, max: 106)
#
# Run: 494, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 18.95, max: 106)
#
# Run: 495, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.7, max: 106)
#
# Run: 496, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.94, max: 106)
#
# Run: 497, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.49, max: 106)
#
# Run: 498, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.42, max: 106)
#
# Run: 499, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.51, max: 106)
#
# Run: 500, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 17.56, max: 106)
#
# Run: 501, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 17.11, max: 106)
#
# Run: 502, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16.9, max: 106)
#
# Run: 503, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 16.23, max: 106)
#
# Run: 504, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 16.08, max: 106)
#
# Run: 505, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 16.31, max: 106)
# Run: 506, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 17.15, max: 106)
#
# Run: 507, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 16.9, max: 106)
#
# Run: 508, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 17.06, max: 106)
#
# Run: 509, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 16.3, max: 98)
#
# Run: 510, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 16.26, max: 98)
#
# Run: 511, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.22, max: 98)
#
# Run: 512, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.83, max: 98)
#
# Run: 513, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.04, max: 98)
#
# Run: 514, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 515, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 516, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.49, max: 98)
#
# Run: 517, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.47, max: 98)
#
# Run: 518, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.48, max: 98)
#
# Run: 519, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.48, max: 98)
#
# Run: 520, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.49, max: 98)
#
# Run: 521, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.49, max: 98)
#
# Run: 522, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 523, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 524, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 525, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 526, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.48, max: 98)
#
# Run: 527, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.49, max: 98)
#
# Run: 528, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.5, max: 98)
#
# Run: 529, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.51, max: 98)
#
# Run: 530, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.53, max: 98)
#
# Run: 531, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.53, max: 98)
#
# Run: 532, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.53, max: 98)
#
# Run: 533, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.53, max: 98)
#
# Run: 534, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 98)
#
# Run: 535, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.55, max: 98)
#
# Run: 536, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.53, max: 98)
#
# Run: 537, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 98)
#
# Run: 538, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 539, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 540, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 541, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 542, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 543, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.55, max: 98)
#
# Run: 544, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.55, max: 98)
#
# Run: 545, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.54, max: 98)
#
# Run: 546, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 547, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.54, max: 98)
#
# Run: 548, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.54, max: 98)
#
# Run: 549, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 550, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.56, max: 98)
#
# Run: 551, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.58, max: 98)
#
# Run: 552, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.58, max: 98)
#
# Run: 553, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.58, max: 98)
#
# Run: 554, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.59, max: 98)
#
# Run: 555, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.59, max: 98)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.59, max: 98)
#
# Run: 557, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.59, max: 98)
#
# Run: 558, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 559, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 560, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 561, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 562, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 563, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 564, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.6, max: 98)
#
# Run: 565, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.61, max: 98)
#
# Run: 566, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.61, max: 98)
#
# Run: 567, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.61, max: 98)
#
# Run: 568, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 14.78, max: 98)
#
# Run: 569, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.78, max: 98)
#
# Run: 570, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.79, max: 98)
#
# Run: 571, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.78, max: 98)
#
# Run: 572, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.78, max: 98)
#
# Run: 573, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.78, max: 98)
#
# Run: 574, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.79, max: 98)
#
# Run: 575, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.8, max: 98)
#
# Run: 576, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.81, max: 98)
#
# Run: 577, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 14.94, max: 98)
#
# Run: 578, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.96, max: 98)
#
# Run: 579, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.97, max: 98)
#
# Run: 580, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.97, max: 98)
#
# Run: 581, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.96, max: 98)
#
# Run: 582, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.98, max: 98)
#
# Run: 583, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.96, max: 98)
#
# Run: 584, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.96, max: 98)
#
# Run: 585, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.95, max: 98)
#
# Run: 586, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.95, max: 98)
#
# Run: 587, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.98, max: 98)
#
# Run: 588, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.95, max: 98)
#
# Run: 589, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.92, max: 98)
#
# Run: 590, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.89, max: 98)
#
# Run: 591, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.82, max: 98)
#
# Run: 592, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.73, max: 98)
#
# Run: 593, exploration: 0.01, score: 9
# ...
#
# Run: 632, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.12, max: 25)
#
# Run: 633, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.13, max: 25)
#
# Run: 634, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.12, max: 25)
#
# Run: 635, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.11, max: 25)
#
# Run: 636, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.13, max: 25)
#
# Run: 637, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.14, max: 25)
#
# Run: 638, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.11, max: 25)
#
# Run: 639, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.12, max: 25)
#
# Run: 640, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.12, max: 25)
#
# Run: 641, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.12, max: 25)
#
# Run: 642, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.26, max: 25)
#
# Run: 643, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.28, max: 25)
#
# Run: 644, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 25)
#
# Run: 645, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.3, max: 25)
#
# Run: 646, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 25)
#
# Run: 647, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.3, max: 25)
#
# Run: 648, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.3, max: 25)
#
# Run: 649, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 25)
#
# Run: 650, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 651, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 652, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.28, max: 25)
#
# Run: 653, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 654, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 655, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 656, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.27, max: 25)
#
# Run: 657, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.31, max: 25)
#
# Run: 658, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.29, max: 25)
#
# Run: 659, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.3, max: 25)
#
# Run: 660, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.32, max: 25)
#
# Run: 661, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.35, max: 25)
#
# Run: 662, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 25)
#
# Run: 663, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.36, max: 25)
#
# Run: 664, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.35, max: 25)
#
# Run: 665, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.38, max: 25)
#
# Run: 666, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.43, max: 25)
#
# Run: 667, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.43, max: 25)
#
# Run: 668, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.28, max: 24)
#
# Run: 669, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 10.43, max: 24)
#
# Run: 670, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.45, max: 24)
#
# Run: 671, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.45, max: 24)
#
# Run: 672, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 24)
#
# Run: 673, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 24)
#
# Run: 674, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.44, max: 24)
#
# Run: 675, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.46, max: 24)
#
# Run: 676, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.44, max: 24)
#
# Run: 677, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.3, max: 24)
#
# Run: 678, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.28, max: 24)
#
# Run: 679, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.27, max: 24)
#
# Run: 680, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 681, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 682, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.24, max: 24)
#
# Run: 683, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 684, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 685, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 686, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 687, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 688, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 689, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 690, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 691, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 692, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 693, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 694, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.19, max: 24)
#
# Run: 695, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 696, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 697, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.19, max: 24)
#
# Run: 698, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.17, max: 24)
#
# Run: 699, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 700, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.16, max: 24)
#
# Run: 701, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.15, max: 24)
#
# Run: 702, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.17, max: 24)
#
# Run: 703, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.2, max: 24)
#
# Run: 704, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 705, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 706, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 707, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 708, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 709, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 710, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 711, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.23, max: 24)
#
# Run: 712, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.23, max: 24)
#
# Run: 713, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 714, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.27, max: 24)
#
# Run: 715, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.27, max: 24)
#
# Run: 716, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.26, max: 24)
#
# Run: 717, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.27, max: 24)
# Run: 718, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 719, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.23, max: 24)
#
# Run: 720, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.17, max: 24)
#
# Run: 721, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 722, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 723, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 724, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 725, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 10.23, max: 24)
#
# Run: 726, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 727, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.26, max: 24)
#
# Run: 728, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.15, max: 24)
#
# Run: 729, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.17, max: 24)
#
# Run: 730, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.18, max: 24)
#
# Run: 731, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.21, max: 24)
#
# Run: 732, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.24, max: 24)
#
# Run: 733, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.32, max: 24)
#
# Run: 734, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.32, max: 24)
#
# Run: 735, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.33, max: 24)
#
# Run: 736, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.34, max: 24)
#
# Run: 737, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.34, max: 24)
#
# Run: 738, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.35, max: 24)
#
# Run: 739, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.34, max: 24)
#
# Run: 740, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.34, max: 24)
#
# Run: 741, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.42, max: 24)
#
# Run: 742, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.26, max: 24)
#
# Run: 743, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.26, max: 24)
#
# Run: 744, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.25, max: 24)
#
# Run: 745, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.22, max: 24)
#
# Run: 746, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.31, max: 24)
#
# Run: 747, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.3, max: 24)
#
# Run: 748, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.29, max: 24)
#
# Run: 749, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.28, max: 24)
#
# Run: 750, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 10.46, max: 28)
#
# Run: 751, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.44, max: 28)
#
# Run: 752, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.45, max: 28)
#
# Run: 753, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 754, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 755, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 756, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.55, max: 28)
#
# Run: 757, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 28)
#
# Run: 758, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 759, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 760, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.57, max: 28)
#
# Run: 761, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.55, max: 28)
#
# Run: 762, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.55, max: 28)
#
# Run: 763, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.54, max: 28)
#
# Run: 764, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.55, max: 28)
#
# Run: 765, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.52, max: 28)
#
# Run: 766, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.51, max: 28)
#
# Run: 767, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 10.64, max: 28)
#
# Run: 768, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 10.85, max: 31)
#
# Run: 769, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.71, max: 31)
#
# Run: 770, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.67, max: 31)
#
# Run: 771, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.67, max: 31)
#
# Run: 772, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.66, max: 31)
#
# Run: 773, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.66, max: 31)
#
# Run: 774, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.68, max: 31)
#
# Run: 775, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.65, max: 31)
#
# Run: 776, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.67, max: 31)
#
# Run: 777, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.67, max: 31)
#
# Run: 778, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.66, max: 31)
#
# Run: 779, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.67, max: 31)
#
# Run: 780, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.69, max: 31)
#
# Run: 781, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.73, max: 31)
#
# Run: 782, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.74, max: 31)
#
# Run: 783, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 10.95, max: 31)
#
# Run: 784, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.94, max: 31)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-0d9ca74c075d> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-0d9ca74c075d> in experience_replay(self)
#      54             if not terminal:
#      55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
# ---> 56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#      58             self.model.fit(state, q_values, verbose=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001 
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 2.0  #change the exploration to larger
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.98005, score: 22
# Scores: (min: 22, avg: 22, max: 22)
#
# Run: 2, exploration: 1.9022202609315437, score: 9
# Scores: (min: 9, avg: 15.5, max: 22)
#
# Run: 3, exploration: 1.7556182834681147, score: 17
# Scores: (min: 9, avg: 16, max: 22)
#
# Run: 4, exploration: 1.4657537092873598, score: 37
# Scores: (min: 9, avg: 21.25, max: 37)
#
# Run: 5, exploration: 1.325936166922741, score: 21
# Scores: (min: 9, avg: 21.2, max: 37)
#
# Run: 6, exploration: 1.2298972430714525, score: 16
# Scores: (min: 9, avg: 20.333333333333332, max: 37)
#
# Run: 7, exploration: 1.0850402445845577, score: 26
# Scores: (min: 9, avg: 21.142857142857142, max: 37)
#
# Run: 8, exploration: 1.0165901475171681, score: 14
# Scores: (min: 9, avg: 20.25, max: 37)
#
# Run: 9, exploration: 0.9335514740318087, score: 18
# Scores: (min: 9, avg: 20, max: 37)
#
# Run: 10, exploration: 0.8277366916839737, score: 25
# Scores: (min: 9, avg: 20.5, max: 37)
#
# Run: 11, exploration: 0.7525419961860931, score: 20
# Scores: (min: 9, avg: 20.454545454545453, max: 37)
#
# Run: 12, exploration: 0.6945444303778464, score: 17
# Scores: (min: 9, avg: 20.166666666666668, max: 37)
#
# Run: 13, exploration: 0.6410166717786715, score: 17
# Scores: (min: 9, avg: 19.923076923076923, max: 37)
#
# Run: 14, exploration: 0.5916142373709133, score: 17
# Scores: (min: 9, avg: 19.714285714285715, max: 37)
#
# Run: 15, exploration: 0.5460191930558976, score: 17
# Scores: (min: 9, avg: 19.533333333333335, max: 37)
#
# Run: 16, exploration: 0.521934056225337, score: 10
# Scores: (min: 9, avg: 18.9375, max: 37)
#
# Run: 17, exploration: 0.4841298343241029, score: 16
# Scores: (min: 9, avg: 18.764705882352942, max: 37)
#
# Run: 18, exploration: 0.3601833314636254, score: 60
# Scores: (min: 9, avg: 21.055555555555557, max: 60)
#
# Run: 19, exploration: 0.22372590912724627, score: 96
# Scores: (min: 9, avg: 25, max: 96)
#
# Run: 20, exploration: 0.17676695328904168, score: 48
# Scores: (min: 9, avg: 26.15, max: 96)
#
# Run: 21, exploration: 0.1355265416262968, score: 54
# Scores: (min: 9, avg: 27.476190476190474, max: 96)
#
# Run: 22, exploration: 0.09735262927663683, score: 67
# Scores: (min: 9, avg: 29.272727272727273, max: 96)
#
# Run: 23, exploration: 0.06958154942772592, score: 68
# Scores: (min: 9, avg: 30.956521739130434, max: 96)
#
# Run: 24, exploration: 0.044095517435140265, score: 92
# Scores: (min: 9, avg: 33.5, max: 96)
#
# Run: 25, exploration: 0.012913656374037803, score: 246
# Scores: (min: 9, avg: 42, max: 246)
#
# Run: 26, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 43.73076923076923, max: 246)
#
# Run: 27, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 45.407407407407405, max: 246)
#
# Run: 28, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 49.285714285714285, max: 246)
#
# Run: 29, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 54.206896551724135, max: 246)
#
# Run: 30, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 61.6, max: 276)
#
# Run: 31, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 66.70967741935483, max: 276)
#
# Run: 32, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 73.0625, max: 276)
#
# Run: 33, exploration: 0.01, score: 405
# Scores: (min: 9, avg: 83.12121212121212, max: 405)
#
# Run: 34, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 86.47058823529412, max: 405)
#
# Run: 35, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 91.51428571428572, max: 405)
#
# Run: 36, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 94.47222222222223, max: 405)
#
# Run: 37, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 98.64864864864865, max: 405)
#
# Run: 38, exploration: 0.01, score: 456
# Scores: (min: 9, avg: 108.05263157894737, max: 456)
#
# Run: 39, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 110.07692307692308, max: 456)
#
# Run: 40, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 112.875, max: 456)
#
# Run: 41, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 113.60975609756098, max: 456)
#
# Run: 42, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 116.11904761904762, max: 456)
#
# Run: 43, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 118.34883720930233, max: 456)
#
# Run: 44, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 120.86363636363636, max: 456)
#
# Run: 45, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 123.66666666666667, max: 456)
#
# Run: 46, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 125.21739130434783, max: 456)
#
# Run: 47, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 125.27659574468085, max: 456)
#
# Run: 48, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 126.625, max: 456)
#
# Run: 49, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 129.3469387755102, max: 456)
#
# Run: 50, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 131.8, max: 456)
#
# Run: 51, exploration: 0.01, score: 267
# Scores: (min: 9, avg: 134.45098039215685, max: 456)
#
# Run: 52, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 136.17307692307693, max: 456)
#
# Run: 53, exploration: 0.01, score: 415
# Scores: (min: 9, avg: 141.43396226415095, max: 456)
#
# Run: 54, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 143.16666666666666, max: 456)
#
# Run: 55, exploration: 0.01, score: 320
# Scores: (min: 9, avg: 146.38181818181818, max: 456)
#
# Run: 56, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 147.125, max: 456)
#
# Run: 57, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 149.6315789473684, max: 456)
#
# Run: 58, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 150.18965517241378, max: 456)
#
# Run: 59, exploration: 0.01, score: 323
# Scores: (min: 9, avg: 153.11864406779662, max: 456)
#
# Run: 60, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 154.51666666666668, max: 456)
#
# Run: 61, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 155.72131147540983, max: 456)
#
# Run: 62, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 156.4516129032258, max: 456)
#
# Run: 63, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 156.57142857142858, max: 456)
#
# Run: 64, exploration: 0.01, score: 383
# Scores: (min: 9, avg: 160.109375, max: 456)
#
# Run: 65, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 161.72307692307692, max: 456)
#
# Run: 66, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 161.74242424242425, max: 456)
#
# Run: 67, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 161.55223880597015, max: 456)
#
# Run: 68, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 166.52941176470588, max: 500)
#
# Run: 69, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 167.2173913043478, max: 500)
#
# Run: 70, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 167.24285714285713, max: 500)
#
# Run: 71, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 167.43661971830986, max: 500)
#
# Run: 72, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 167.30555555555554, max: 500)
#
# Run: 73, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 167.6986301369863, max: 500)
#
# Run: 74, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 168.56756756756758, max: 500)
#
# Run: 75, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 168.37333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 168.21052631578948, max: 500)
#
# Run: 77, exploration: 0.01, score: 335
# Scores: (min: 9, avg: 170.37662337662337, max: 500)
#
# Run: 78, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 170.37179487179486, max: 500)
#
# Run: 79, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 170.56962025316454, max: 500)
#
# Run: 80, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 171.975, max: 500)
#
# Run: 81, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 172.46913580246914, max: 500)
#
# Run: 82, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 173.09756097560975, max: 500)
#
# Run: 83, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 174.53012048192772, max: 500)
#
# Run: 84, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 174.63095238095238, max: 500)
#
# Run: 85, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 175.69411764705882, max: 500)
#
# Run: 86, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 175.03488372093022, max: 500)
#
# Run: 87, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 174.55172413793105, max: 500)
#
# Run: 88, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 175.0340909090909, max: 500)
#
# Run: 89, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 175.96629213483146, max: 500)
#
# Run: 90, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 179.56666666666666, max: 500)
# Run: 91, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 180.2967032967033, max: 500)
#
# Run: 92, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 181.02173913043478, max: 500)
#
# Run: 93, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 180.32258064516128, max: 500)
#
# Run: 94, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 179.5744680851064, max: 500)
#
# Run: 95, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 178.69473684210527, max: 500)
#
# Run: 96, exploration: 0.01, score: 76
# Scores: (min: 9, avg: 177.625, max: 500)
#
# Run: 97, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 176.24742268041237, max: 500)
#
# Run: 98, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 175.46938775510205, max: 500)
#
# Run: 99, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 175.43434343434345, max: 500)
#
# Run: 100, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 175.11, max: 500)
#
# Run: 101, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 175.5, max: 500)
#
# Run: 102, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 175.96, max: 500)
#
# Run: 103, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 177.89, max: 500)
#
# Run: 104, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 178.44, max: 500)
#
# Run: 105, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 178.34, max: 500)
#
# Run: 106, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 178.28, max: 500)
#
# Run: 107, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 178.1, max: 500)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 178.05, max: 500)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 177.97, max: 500)
#
# Run: 110, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.81, max: 500)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 177.71, max: 500)
#
# Run: 112, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.63, max: 500)
#
# Run: 113, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.55, max: 500)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 177.48, max: 500)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.4, max: 500)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.39, max: 500)
#
# Run: 117, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 177.33, max: 500)
#
# Run: 118, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 176.82, max: 500)
#
# Run: 119, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 175.94, max: 500)
#
# Run: 120, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 175.57, max: 500)
#
# Run: 121, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 175.12, max: 500)
#
# Run: 122, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 174.54, max: 500)
#
# Run: 123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 173.96, max: 500)
#
# Run: 124, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 173.15, max: 500)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 170.79, max: 500)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 170.02, max: 500)
#
# Run: 127, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 169.22, max: 500)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 167.78, max: 500)
#
# Run: 129, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 165.98, max: 500)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 163.32, max: 500)
#
# Run: 131, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 161.3, max: 500)
#
# Run: 132, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 160.96, max: 500)
#
# Run: 133, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 161.91, max: 500)
#
# Run: 134, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 161.3, max: 500)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 163.67, max: 500)
#
# Run: 136, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 163.91, max: 500)
#
# Run: 137, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 166.42, max: 500)
#
# Run: 138, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 166.86, max: 500)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 169.99, max: 500)
#
# Run: 140, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 172.77, max: 500)
#
# Run: 141, exploration: 0.01, score: 378
# Scores: (min: 8, avg: 175.12, max: 500)
#
# Run: 142, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 174.05, max: 500)
#
# Run: 143, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 172.5, max: 500)
#
# Run: 144, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 170.33, max: 500)
#
# Run: 145, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 167.97, max: 500)
#
# Run: 146, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 168.42, max: 500)
#
# Run: 147, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 172.14, max: 500)
#
# Run: 148, exploration: 0.01, score: 350
# Scores: (min: 8, avg: 173.74, max: 500)
#
# Run: 149, exploration: 0.01, score: 425
# Scores: (min: 8, avg: 175.39, max: 500)
#
# Run: 150, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 175.44, max: 500)
#
# Run: 151, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 174.54, max: 500)
#
# Run: 152, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 174.6, max: 500)
#
# Run: 153, exploration: 0.01, score: 315
# Scores: (min: 8, avg: 173.6, max: 500)
#
# Run: 154, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 173.91, max: 500)
#
# Run: 155, exploration: 0.01, score: 372
# Scores: (min: 8, avg: 174.43, max: 500)
#
# Run: 156, exploration: 0.01, score: 415
# Scores: (min: 8, avg: 176.7, max: 500)
#
# Run: 157, exploration: 0.01, score: 329
# Scores: (min: 8, avg: 177.09, max: 500)
#
# Run: 158, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 180.27, max: 500)
#
# Run: 159, exploration: 0.01, score: 383
# Scores: (min: 8, avg: 180.87, max: 500)
#
# Run: 160, exploration: 0.01, score: 355
# Scores: (min: 8, avg: 182.05, max: 500)
#
# Run: 161, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 181.14, max: 500)
#
# Run: 162, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 184.13, max: 500)
#
# Run: 163, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 187.49, max: 500)
#
# Run: 164, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 186.5, max: 500)
#
# Run: 165, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 186, max: 500)
#
# Run: 166, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 185.83, max: 500)
#
# Run: 167, exploration: 0.01, score: 498
# Scores: (min: 8, avg: 189.32, max: 500)
#
# Run: 168, exploration: 0.01, score: 376
# Scores: (min: 8, avg: 188.08, max: 500)
#
# Run: 169, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 190.94, max: 500)
#
# Run: 170, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 190.81, max: 500)
#
# Run: 171, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 191.47, max: 500)
#
# Run: 172, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 191.39, max: 500)
#
# Run: 173, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 191.9, max: 500)
#
# Run: 174, exploration: 0.01, score: 328
# Scores: (min: 8, avg: 192.86, max: 500)
#
# Run: 175, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 193.08, max: 500)
#
# Run: 176, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 191.7, max: 500)
#
# Run: 177, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 189.34, max: 500)
#
# Run: 178, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 190.45, max: 500)
#
# Run: 179, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 190.12, max: 500)
#
# Run: 180, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 188.56, max: 500)
#
# Run: 181, exploration: 0.01, score: 363
# Scores: (min: 8, avg: 190.07, max: 500)
#
# Run: 182, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 189.68, max: 500)
#
# Run: 183, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 188.59, max: 500)
#
# Run: 184, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 187.45, max: 500)
#
# Run: 185, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 186.63, max: 500)
#
# Run: 186, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 187.69, max: 500)
#
# Run: 187, exploration: 0.01, score: 403
# Scores: (min: 8, avg: 190.39, max: 500)
#
# Run: 188, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 189.74, max: 500)
#
# Run: 189, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 188.83, max: 500)
#
# Run: 190, exploration: 0.01, score: 287
# Scores: (min: 8, avg: 186.7, max: 500)
#
# Run: 191, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 186, max: 500)
# Run: 192, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 183.62, max: 500)
#
# Run: 193, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 182.57, max: 500)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 181.57, max: 500)
#
# Run: 195, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 180.76, max: 500)
#
# Run: 196, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 180.16, max: 500)
#
# Run: 197, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 184.72, max: 500)
#
# Run: 198, exploration: 0.01, score: 419
# Scores: (min: 8, avg: 187.91, max: 500)
#
# Run: 199, exploration: 0.01, score: 437
# Scores: (min: 8, avg: 190.56, max: 500)
#
# Run: 200, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 191.84, max: 500)
#
# Run: 201, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 192.98, max: 500)
#
# Run: 202, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 194.75, max: 500)
#
# Run: 203, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 193.07, max: 500)
#
# Run: 204, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 192.36, max: 500)
#
# Run: 205, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 194.01, max: 500)
#
# Run: 206, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 194.14, max: 500)
#
# Run: 207, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 195.74, max: 500)
#
# Solved in 107 runs, 207 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-4-184a657c96e7> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.5  #change decay rate
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.01, score: 17
# Scores: (min: 13, avg: 15, max: 17)
#
# Run: 3, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 13.666666666666666, max: 17)
#
# Run: 4, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.5, max: 17)
#
# Run: 5, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 11.8, max: 17)
#
# Run: 6, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 11.5, max: 17)
#
# Run: 7, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 11.571428571428571, max: 17)
#
# Run: 8, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 16.25, max: 49)
#
# Run: 9, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 15.444444444444445, max: 49)
#
# Run: 10, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 14.8, max: 49)
#
# Run: 11, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 14.363636363636363, max: 49)
#
# Run: 12, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13.916666666666666, max: 49)
#
# Run: 13, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13.538461538461538, max: 49)
#
# Run: 14, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.142857142857142, max: 49)
#
# Run: 15, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.866666666666667, max: 49)
#
# Run: 16, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.6875, max: 49)
#
# Run: 17, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.529411764705882, max: 49)
#
# Run: 18, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 14.833333333333334, max: 54)
#
# Run: 19, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 15.210526315789474, max: 54)
#
# Run: 20, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.1, max: 54)
#
# Run: 21, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.047619047619047, max: 54)
#
# Run: 22, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.454545454545455, max: 54)
#
# Run: 23, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 16, max: 54)
#
# Run: 24, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.875, max: 54)
#
# Run: 25, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 18, max: 54)
#
# Run: 26, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 18.73076923076923, max: 54)
#
# Run: 27, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.22222222222222, max: 54)
#
# Run: 28, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 19.75, max: 54)
#
# Run: 29, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 20.517241379310345, max: 54)
#
# Run: 30, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 22.566666666666666, max: 82)
#
# Run: 31, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 24.161290322580644, max: 82)
#
# Run: 32, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 25.96875, max: 82)
#
# Run: 33, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 27.03030303030303, max: 82)
#
# Run: 34, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 28.176470588235293, max: 82)
#
# Run: 35, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 29.34285714285714, max: 82)
#
# Run: 36, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 30.166666666666668, max: 82)
#
# Run: 37, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 31.216216216216218, max: 82)
#
# Run: 38, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 31.789473684210527, max: 82)
#
# Run: 39, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 32.666666666666664, max: 82)
#
# Run: 40, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 33, max: 82)
#
# Run: 41, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 33.853658536585364, max: 82)
#
# Run: 42, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 35.23809523809524, max: 92)
#
# Run: 43, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 36.116279069767444, max: 92)
#
# Run: 44, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 36.95454545454545, max: 92)
#
# Run: 45, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 38.24444444444445, max: 95)
#
# Run: 46, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 39.19565217391305, max: 95)
#
# Run: 47, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 40.8936170212766, max: 119)
#
# Run: 48, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 42.333333333333336, max: 119)
#
# Run: 49, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 43.95918367346939, max: 122)
#
# Run: 50, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 45.48, max: 122)
#
# Run: 51, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 47.03921568627451, max: 125)
#
# Run: 52, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 48.51923076923077, max: 125)
#
# Run: 53, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 49.81132075471698, max: 125)
#
# Run: 54, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 50.888888888888886, max: 125)
#
# Run: 55, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 52.2, max: 125)
#
# Run: 56, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 53.964285714285715, max: 151)
#
# Run: 57, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 55.03508771929825, max: 151)
#
# Run: 58, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 56.241379310344826, max: 151)
#
# Run: 59, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 57.32203389830509, max: 151)
#
# Run: 60, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 58.81666666666667, max: 151)
#
# Run: 61, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 60, max: 151)
#
# Run: 62, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 61.37096774193548, max: 151)
#
# Run: 63, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 62.26984126984127, max: 151)
#
# Run: 64, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 63.359375, max: 151)
#
# Run: 65, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 64.0923076923077, max: 151)
#
# Run: 66, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 65.06060606060606, max: 151)
#
# Run: 67, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 65.86567164179104, max: 151)
#
# Run: 68, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 66.79411764705883, max: 151)
#
# Run: 69, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 68.23188405797102, max: 166)
#
# Run: 70, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 69.15714285714286, max: 166)
#
# Run: 71, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 69.73239436619718, max: 166)
#
# Run: 72, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 70.54166666666667, max: 166)
#
# Run: 73, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 71.58904109589041, max: 166)
#
# Run: 74, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 72.95945945945945, max: 173)
#
# Run: 75, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 73.54666666666667, max: 173)
#
# Run: 76, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 74.23684210526316, max: 173)
#
# Run: 77, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 75, max: 173)
#
# Run: 78, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 75.62820512820512, max: 173)
#
# Run: 79, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 76.07594936708861, max: 173)
#
# Run: 80, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 76.525, max: 173)
#
# Run: 81, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 77.32098765432099, max: 173)
#
# Run: 82, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 77.6951219512195, max: 173)
#
# Run: 83, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 78.24096385542168, max: 173)
#
# Run: 84, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 78.95238095238095, max: 173)
#
# Run: 85, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 79.45882352941176, max: 173)
#
# Run: 86, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 80.04651162790698, max: 173)
#
# Run: 87, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 80.42528735632185, max: 173)
#
# Run: 88, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 81.23863636363636, max: 173)
#
# Run: 89, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 81.80898876404494, max: 173)
#
# Run: 90, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 82.32222222222222, max: 173)
#
# Run: 91, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 82.54945054945055, max: 173)
#
# Run: 92, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 83.29347826086956, max: 173)
#
# Run: 93, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 83.51612903225806, max: 173)
#
# Run: 94, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 83.87234042553192, max: 173)
# Run: 95, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 84.15789473684211, max: 173)
#
# Run: 96, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 84.48958333333333, max: 173)
#
# Run: 97, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 85.30927835051547, max: 173)
#
# Run: 98, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 85.5, max: 173)
#
# Run: 99, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 85.97979797979798, max: 173)
#
# Run: 100, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 86.19, max: 173)
#
# Run: 101, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 87.37, max: 173)
#
# Run: 102, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 88.36, max: 173)
#
# Run: 103, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 89.31, max: 173)
#
# Run: 104, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 90.77, max: 173)
#
# Run: 105, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 92.15, max: 173)
#
# Run: 106, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 93.13, max: 173)
#
# Run: 107, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 94.1, max: 173)
#
# Run: 108, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 94.63, max: 173)
#
# Run: 109, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 94.66, max: 173)
#
# Run: 110, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 95.91, max: 173)
#
# Run: 111, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 97.06, max: 173)
#
# Run: 112, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 98.04, max: 173)
#
# Run: 113, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 98.94, max: 173)
#
# Run: 114, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 100.11, max: 173)
#
# Run: 115, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 101, max: 173)
#
# Run: 116, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 101.89, max: 173)
#
# Run: 117, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 102.86, max: 173)
#
# Run: 118, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 103.68, max: 173)
#
# Run: 119, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 104.69, max: 173)
#
# Run: 120, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 105.69, max: 173)
#
# Run: 121, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 106.57, max: 173)
#
# Run: 122, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 107.63, max: 173)
#
# Run: 123, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 108.79, max: 173)
#
# Run: 124, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 109.44, max: 173)
#
# Run: 125, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 110.12, max: 173)
#
# Run: 126, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 111.03, max: 173)
#
# Run: 127, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 112.02, max: 173)
#
# Run: 128, exploration: 0.01, score: 147
# Scores: (min: 12, avg: 113.15, max: 173)
#
# Run: 129, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 114.1, max: 173)
#
# Run: 130, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 114.58, max: 173)
#
# Run: 131, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 115.21, max: 173)
#
# Run: 132, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 115.59, max: 173)
#
# Run: 133, exploration: 0.01, score: 161
# Scores: (min: 12, avg: 116.59, max: 173)
#
# Run: 134, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 117.16, max: 173)
#
# Run: 135, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 117.7, max: 173)
#
# Run: 136, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 118.21, max: 173)
#
# Run: 137, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 118.63, max: 173)
#
# Run: 138, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 119.46, max: 173)
#
# Run: 139, exploration: 0.01, score: 160
# Scores: (min: 12, avg: 120.4, max: 173)
#
# Run: 140, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 121.12, max: 173)
#
# Run: 141, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 121.79, max: 173)
#
# Run: 142, exploration: 0.01, score: 110
# Scores: (min: 12, avg: 121.97, max: 173)
#
# Run: 143, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 122.33, max: 173)
#
# Run: 144, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 122.96, max: 173)
#
# Run: 145, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 123.08, max: 173)
#
# Run: 146, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 123.59, max: 173)
#
# Run: 147, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 123.54, max: 173)
#
# Run: 148, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 123.9, max: 173)
#
# Run: 149, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 123.94, max: 173)
#
# Run: 150, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 123.83, max: 173)
#
# Run: 151, exploration: 0.01, score: 113
# Scores: (min: 12, avg: 123.71, max: 173)
#
# Run: 152, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 123.68, max: 173)
#
# Run: 153, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 123.8, max: 173)
#
# Run: 154, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 123.88, max: 173)
#
# Run: 155, exploration: 0.01, score: 156
# Scores: (min: 12, avg: 124.21, max: 173)
#
# Run: 156, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 123.86, max: 173)
#
# Run: 157, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 124.09, max: 173)
#
# Run: 158, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 124.02, max: 173)
#
# Run: 159, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 123.76, max: 173)
#
# Run: 160, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 123.19, max: 173)
#
# Run: 161, exploration: 0.01, score: 96
# Scores: (min: 12, avg: 122.84, max: 173)
#
# Run: 162, exploration: 0.01, score: 82
# Scores: (min: 12, avg: 122.21, max: 173)
#
# Run: 163, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 122.71, max: 173)
#
# Run: 164, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 122.79, max: 173)
#
# Run: 165, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 122.96, max: 173)
#
# Run: 166, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 122.93, max: 173)
#
# Run: 167, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 123.09, max: 173)
#
# Run: 168, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 122.07, max: 173)
#
# Run: 169, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 121.45, max: 173)
#
# Run: 170, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 121.31, max: 173)
#
# Run: 171, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 121.3, max: 173)
#
# Run: 172, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 121.1, max: 173)
#
# Run: 173, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 119.76, max: 173)
#
# Run: 174, exploration: 0.01, score: 66
# Scores: (min: 12, avg: 118.69, max: 168)
#
# Run: 175, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 118.31, max: 168)
#
# Run: 176, exploration: 0.01, score: 264
# Scores: (min: 12, avg: 119.69, max: 264)
#
# Run: 177, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 119.51, max: 264)
#
# Run: 178, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 119.14, max: 264)
#
# Run: 179, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 119.26, max: 264)
#
# Run: 180, exploration: 0.01, score: 118
# Scores: (min: 12, avg: 119.32, max: 264)
#
# Run: 181, exploration: 0.01, score: 317
# Scores: (min: 12, avg: 121.08, max: 317)
#
# Run: 182, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 121.04, max: 317)
#
# Run: 183, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 121.03, max: 317)
#
# Run: 184, exploration: 0.01, score: 148
# Scores: (min: 12, avg: 121.13, max: 317)
#
# Run: 185, exploration: 0.01, score: 121
# Scores: (min: 12, avg: 121.12, max: 317)
#
# Run: 186, exploration: 0.01, score: 141
# Scores: (min: 12, avg: 121.23, max: 317)
#
# Run: 187, exploration: 0.01, score: 230
# Scores: (min: 12, avg: 122.4, max: 317)
#
# Run: 188, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 122.12, max: 317)
#
# Run: 189, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 121.51, max: 317)
#
# Run: 190, exploration: 0.01, score: 20
# Scores: (min: 12, avg: 120.43, max: 317)
#
# Run: 191, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 120.63, max: 317)
#
# Run: 192, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 119.88, max: 317)
#
# Run: 193, exploration: 0.01, score: 60
# Scores: (min: 12, avg: 119.44, max: 317)
#
# Run: 194, exploration: 0.01, score: 180
# Scores: (min: 12, avg: 120.07, max: 317)
#
# Run: 195, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 119.21, max: 317)
# Run: 196, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 119.02, max: 317)
#
# Run: 197, exploration: 0.01, score: 240
# Scores: (min: 12, avg: 119.78, max: 317)
#
# Run: 198, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 119.9, max: 317)
#
# Run: 199, exploration: 0.01, score: 166
# Scores: (min: 12, avg: 120.23, max: 317)
#
# Run: 200, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 120, max: 317)
#
# Run: 201, exploration: 0.01, score: 208
# Scores: (min: 12, avg: 120.77, max: 317)
#
# Run: 202, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 120.88, max: 317)
#
# Run: 203, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 120.89, max: 317)
#
# Run: 204, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 120.64, max: 317)
#
# Run: 205, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 120.52, max: 317)
#
# Run: 206, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 120.73, max: 317)
#
# Run: 207, exploration: 0.01, score: 146
# Scores: (min: 12, avg: 121.1, max: 317)
#
# Run: 208, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 121.09, max: 317)
#
# Run: 209, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 123, max: 317)
#
# Run: 210, exploration: 0.01, score: 137
# Scores: (min: 13, avg: 123.03, max: 317)
#
# Run: 211, exploration: 0.01, score: 159
# Scores: (min: 13, avg: 123.37, max: 317)
#
# Run: 212, exploration: 0.01, score: 97
# Scores: (min: 13, avg: 123.27, max: 317)
#
# Run: 213, exploration: 0.01, score: 143
# Scores: (min: 13, avg: 123.71, max: 317)
#
# Run: 214, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 123.6, max: 317)
#
# Run: 215, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 124.01, max: 317)
#
# Run: 216, exploration: 0.01, score: 123
# Scores: (min: 13, avg: 124.25, max: 317)
#
# Run: 217, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 124.21, max: 317)
#
# Run: 218, exploration: 0.01, score: 100
# Scores: (min: 13, avg: 123.85, max: 317)
#
# Run: 219, exploration: 0.01, score: 106
# Scores: (min: 13, avg: 123.68, max: 317)
#
# Run: 220, exploration: 0.01, score: 135
# Scores: (min: 13, avg: 123.9, max: 317)
#
# Run: 221, exploration: 0.01, score: 104
# Scores: (min: 13, avg: 123.92, max: 317)
#
# Run: 222, exploration: 0.01, score: 113
# Scores: (min: 13, avg: 123.75, max: 317)
#
# Run: 223, exploration: 0.01, score: 107
# Scores: (min: 13, avg: 123.38, max: 317)
#
# Run: 224, exploration: 0.01, score: 116
# Scores: (min: 13, avg: 123.52, max: 317)
#
# Run: 225, exploration: 0.01, score: 118
# Scores: (min: 13, avg: 123.57, max: 317)
#
# Run: 226, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 123.46, max: 317)
#
# Run: 227, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 123.83, max: 317)
#
# Run: 228, exploration: 0.01, score: 202
# Scores: (min: 13, avg: 124.38, max: 317)
#
# Run: 229, exploration: 0.01, score: 129
# Scores: (min: 13, avg: 124.3, max: 317)
#
# Run: 230, exploration: 0.01, score: 126
# Scores: (min: 13, avg: 124.26, max: 317)
#
# Run: 231, exploration: 0.01, score: 123
# Scores: (min: 13, avg: 124.14, max: 317)
#
# Run: 232, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 123.95, max: 317)
#
# Run: 233, exploration: 0.01, score: 108
# Scores: (min: 13, avg: 123.42, max: 317)
#
# Run: 234, exploration: 0.01, score: 206
# Scores: (min: 13, avg: 124.25, max: 317)
#
# Run: 235, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 124.68, max: 317)
#
# Run: 236, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 124.9, max: 317)
#
# Run: 237, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 125.11, max: 317)
#
# Run: 238, exploration: 0.01, score: 128
# Scores: (min: 13, avg: 125.03, max: 317)
#
# Run: 239, exploration: 0.01, score: 186
# Scores: (min: 13, avg: 125.29, max: 317)
#
# Run: 240, exploration: 0.01, score: 118
# Scores: (min: 13, avg: 125.29, max: 317)
#
# Run: 241, exploration: 0.01, score: 111
# Scores: (min: 13, avg: 125.05, max: 317)
#
# Run: 242, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 125.47, max: 317)
#
# Run: 243, exploration: 0.01, score: 97
# Scores: (min: 13, avg: 125.35, max: 317)
#
# Run: 244, exploration: 0.01, score: 173
# Scores: (min: 13, avg: 125.72, max: 317)
#
# Run: 245, exploration: 0.01, score: 111
# Scores: (min: 13, avg: 125.76, max: 317)
#
# Run: 246, exploration: 0.01, score: 78
# Scores: (min: 13, avg: 125.21, max: 317)
#
# Run: 247, exploration: 0.01, score: 87
# Scores: (min: 13, avg: 124.94, max: 317)
#
# Run: 248, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 124.65, max: 317)
#
# Run: 249, exploration: 0.01, score: 195
# Scores: (min: 13, avg: 125.34, max: 317)
#
# Run: 250, exploration: 0.01, score: 128
# Scores: (min: 13, avg: 125.53, max: 317)
#
# Run: 251, exploration: 0.01, score: 112
# Scores: (min: 13, avg: 125.52, max: 317)
#
# Run: 252, exploration: 0.01, score: 122
# Scores: (min: 13, avg: 125.53, max: 317)
#
# Run: 253, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 125.91, max: 317)
#
# Run: 254, exploration: 0.01, score: 120
# Scores: (min: 13, avg: 125.95, max: 317)
#
# Run: 255, exploration: 0.01, score: 113
# Scores: (min: 13, avg: 125.52, max: 317)
#
# Run: 256, exploration: 0.01, score: 235
# Scores: (min: 13, avg: 126.71, max: 317)
#
# Run: 257, exploration: 0.01, score: 112
# Scores: (min: 13, avg: 126.45, max: 317)
#
# Run: 258, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 126.58, max: 317)
#
# Run: 259, exploration: 0.01, score: 123
# Scores: (min: 13, avg: 126.87, max: 317)
#
# Run: 260, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 127.06, max: 317)
#
# Run: 261, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 127.13, max: 317)
#
# Run: 262, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 127.99, max: 317)
#
# Run: 263, exploration: 0.01, score: 110
# Scores: (min: 13, avg: 127.41, max: 317)
#
# Run: 264, exploration: 0.01, score: 108
# Scores: (min: 13, avg: 127.09, max: 317)
#
# Run: 265, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 125.93, max: 317)
#
# Run: 266, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 124.8, max: 317)
#
# Run: 267, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 123.61, max: 317)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 123.43, max: 317)
#
# Run: 269, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 122.53, max: 317)
#
# Run: 270, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 121.46, max: 317)
#
# Run: 271, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 120.48, max: 317)
#
# Run: 272, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 120.46, max: 317)
#
# Run: 273, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 121.52, max: 317)
#
# Run: 274, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 122.4, max: 317)
#
# Run: 275, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 123.24, max: 317)
#
# Run: 276, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 121.97, max: 317)
#
# Run: 277, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 122.18, max: 317)
#
# Run: 278, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 123.02, max: 317)
#
# Run: 279, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 123.05, max: 317)
#
# Run: 280, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 122.96, max: 317)
#
# Run: 281, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 120.84, max: 240)
#
# Run: 282, exploration: 0.01, score: 103
# Scores: (min: 9, avg: 120.83, max: 240)
#
# Run: 283, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 120.53, max: 240)
#
# Run: 284, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 121.06, max: 240)
#
# Run: 285, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 122.48, max: 263)
#
# Run: 286, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 122.35, max: 263)
#
# Run: 287, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 121.89, max: 263)
#
# Run: 288, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 121.73, max: 263)
#
# Run: 289, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 122.56, max: 263)
#
# Run: 290, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 122.83, max: 263)
#
# Run: 291, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 122.78, max: 263)
#
# Run: 292, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 123.03, max: 263)
#
# Run: 293, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 123.72, max: 263)
#
# Run: 294, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 123.24, max: 263)
#
# Run: 295, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 124.1, max: 263)
#
# Run: 296, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 124.3, max: 263)
# Run: 297, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 123.02, max: 263)
#
# Run: 298, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 123.02, max: 263)
#
# Run: 299, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 122.72, max: 263)
#
# Run: 300, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 123.51, max: 263)
#
# Run: 301, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 122.78, max: 263)
#
# Run: 302, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 122.76, max: 263)
#
# Run: 303, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 123, max: 263)
#
# Run: 304, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 123.4, max: 263)
#
# Run: 305, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 123.06, max: 263)
#
# Run: 306, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 122.79, max: 263)
#
# Run: 307, exploration: 0.01, score: 269
# Scores: (min: 9, avg: 124.02, max: 269)
#
# Run: 308, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 124.12, max: 269)
#
# Run: 309, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 123.37, max: 269)
#
# Run: 310, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 123.04, max: 269)
#
# Run: 311, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 122.49, max: 269)
#
# Run: 312, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 123.76, max: 269)
#
# Run: 313, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 123.39, max: 269)
#
# Run: 314, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 123.53, max: 269)
#
# Run: 315, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 123.25, max: 269)
#
# Run: 316, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 123.21, max: 269)
#
# Run: 317, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 123.3, max: 269)
#
# Run: 318, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 124.33, max: 269)
#
# Run: 319, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 125.01, max: 269)
#
# Run: 320, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 124.59, max: 269)
#
# Run: 321, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 125.46, max: 269)
#
# Run: 322, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 125.54, max: 269)
#
# Run: 323, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 125.6, max: 269)
#
# Run: 324, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 125.64, max: 269)
#
# Run: 325, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 125.86, max: 269)
#
# Run: 326, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 125.76, max: 269)
#
# Run: 327, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 125.64, max: 269)
#
# Run: 328, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 125.57, max: 269)
#
# Run: 329, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 125.43, max: 269)
#
# Run: 330, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 125.4, max: 269)
#
# Run: 331, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 125.45, max: 269)
#
# Run: 332, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 125.51, max: 269)
#
# Run: 333, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 125.4, max: 269)
#
# Run: 334, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 124.67, max: 269)
#
# Run: 335, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 124.66, max: 269)
#
# Run: 336, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 124.93, max: 269)
#
# Run: 337, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 124.59, max: 269)
#
# Run: 338, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 124.28, max: 269)
#
# Run: 339, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 123.4, max: 269)
#
# Run: 340, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 123.26, max: 269)
#
# Run: 341, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 123.76, max: 269)
#
# Run: 342, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 123.36, max: 269)
#
# Run: 343, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 123.7, max: 269)
#
# Run: 344, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 122.27, max: 269)
#
# Run: 345, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 122.48, max: 269)
#
# Run: 346, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 122.84, max: 269)
#
# Run: 347, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 122.74, max: 269)
#
# Run: 348, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 122.76, max: 269)
#
# Run: 349, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 121.87, max: 269)
#
# Run: 350, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 121.89, max: 269)
#
# Run: 351, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 122.34, max: 269)
#
# Run: 352, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 122.37, max: 269)
#
# Run: 353, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 121.89, max: 269)
#
# Run: 354, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 122.24, max: 269)
#
# Run: 355, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 122.84, max: 269)
#
# Run: 356, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 121.34, max: 269)
#
# Run: 357, exploration: 0.01, score: 160
# Scores: (min: 9, avg: 121.82, max: 269)
#
# Run: 358, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 121.58, max: 269)
#
# Run: 359, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 121.46, max: 269)
#
# Run: 360, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 121.64, max: 269)
#
# Run: 361, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 121.74, max: 269)
#
# Run: 362, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 121.34, max: 269)
#
# Run: 363, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 121.37, max: 269)
#
# Run: 364, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 121.75, max: 269)
#
# Run: 365, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 122.63, max: 269)
#
# Run: 366, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 123.82, max: 269)
#
# Run: 367, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 124.88, max: 269)
#
# Run: 368, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 125.92, max: 269)
#
# Run: 369, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 126.51, max: 269)
#
# Run: 370, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 127.4, max: 269)
#
# Run: 371, exploration: 0.01, score: 93
# Scores: (min: 30, avg: 128.22, max: 269)
#
# Run: 372, exploration: 0.01, score: 125
# Scores: (min: 30, avg: 128.41, max: 269)
#
# Run: 373, exploration: 0.01, score: 105
# Scores: (min: 30, avg: 128.27, max: 269)
#
# Run: 374, exploration: 0.01, score: 109
# Scores: (min: 30, avg: 127.82, max: 269)
#
# Run: 375, exploration: 0.01, score: 123
# Scores: (min: 30, avg: 127.42, max: 269)
#
# Run: 376, exploration: 0.01, score: 36
# Scores: (min: 30, avg: 126.41, max: 269)
#
# Run: 377, exploration: 0.01, score: 119
# Scores: (min: 30, avg: 126.24, max: 269)
#
# Run: 378, exploration: 0.01, score: 107
# Scores: (min: 30, avg: 125.6, max: 269)
#
# Run: 379, exploration: 0.01, score: 46
# Scores: (min: 30, avg: 124.8, max: 269)
#
# Run: 380, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 123.87, max: 269)
#
# Run: 381, exploration: 0.01, score: 145
# Scores: (min: 16, avg: 124.27, max: 269)
#
# Run: 382, exploration: 0.01, score: 100
# Scores: (min: 16, avg: 124.24, max: 269)
#
# Run: 383, exploration: 0.01, score: 91
# Scores: (min: 16, avg: 124.23, max: 269)
#
# Run: 384, exploration: 0.01, score: 113
# Scores: (min: 16, avg: 123.35, max: 269)
#
# Run: 385, exploration: 0.01, score: 102
# Scores: (min: 16, avg: 121.74, max: 269)
#
# Run: 386, exploration: 0.01, score: 149
# Scores: (min: 16, avg: 121.95, max: 269)
#
# Run: 387, exploration: 0.01, score: 117
# Scores: (min: 16, avg: 121.28, max: 269)
#
# Run: 388, exploration: 0.01, score: 178
# Scores: (min: 16, avg: 121.98, max: 269)
#
# Run: 389, exploration: 0.01, score: 179
# Scores: (min: 16, avg: 122.23, max: 269)
#
# Run: 390, exploration: 0.01, score: 123
# Scores: (min: 16, avg: 122.99, max: 269)
#
# Run: 391, exploration: 0.01, score: 134
# Scores: (min: 16, avg: 123.15, max: 269)
#
# Run: 392, exploration: 0.01, score: 120
# Scores: (min: 16, avg: 123.34, max: 269)
#
# Run: 393, exploration: 0.01, score: 109
# Scores: (min: 16, avg: 123.14, max: 269)
#
# Run: 394, exploration: 0.01, score: 116
# Scores: (min: 16, avg: 122.98, max: 269)
#
# Run: 395, exploration: 0.01, score: 129
# Scores: (min: 16, avg: 123.16, max: 269)
#
# Run: 396, exploration: 0.01, score: 281
# Scores: (min: 16, avg: 124.8, max: 281)
#
# Run: 397, exploration: 0.01, score: 102
# Scores: (min: 16, avg: 124.7, max: 281)
#
# Run: 398, exploration: 0.01, score: 114
# Scores: (min: 16, avg: 124.68, max: 281)
# Run: 399, exploration: 0.01, score: 98
# Scores: (min: 16, avg: 124.3, max: 281)
#
# Run: 400, exploration: 0.01, score: 111
# Scores: (min: 16, avg: 123.78, max: 281)
#
# Run: 401, exploration: 0.01, score: 135
# Scores: (min: 16, avg: 123.78, max: 281)
#
# Run: 402, exploration: 0.01, score: 121
# Scores: (min: 16, avg: 123.74, max: 281)
#
# Run: 403, exploration: 0.01, score: 180
# Scores: (min: 16, avg: 124.23, max: 281)
#
# Run: 404, exploration: 0.01, score: 109
# Scores: (min: 16, avg: 123.62, max: 281)
#
# Run: 405, exploration: 0.01, score: 139
# Scores: (min: 16, avg: 124, max: 281)
#
# Run: 406, exploration: 0.01, score: 150
# Scores: (min: 16, avg: 124.48, max: 281)
#
# Run: 407, exploration: 0.01, score: 135
# Scores: (min: 16, avg: 123.14, max: 281)
#
# Run: 408, exploration: 0.01, score: 126
# Scores: (min: 16, avg: 123.29, max: 281)
#
# Run: 409, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 122.13, max: 281)
#
# Run: 410, exploration: 0.01, score: 122
# Scores: (min: 12, avg: 122.31, max: 281)
#
# Run: 411, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 122.34, max: 281)
#
# Run: 412, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 121.46, max: 281)
#
# Run: 413, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 121.73, max: 281)
#
# Run: 414, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 121.76, max: 281)
#
# Run: 415, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 121.96, max: 281)
#
# Run: 416, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 122.01, max: 281)
#
# Run: 417, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 122.15, max: 281)
#
# Run: 418, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 121.26, max: 281)
#
# Run: 419, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 121.28, max: 281)
#
# Run: 420, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 121.49, max: 281)
#
# Run: 421, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 120.98, max: 281)
#
# Run: 422, exploration: 0.01, score: 179
# Scores: (min: 12, avg: 121.56, max: 281)
#
# Run: 423, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 122.08, max: 281)
#
# Run: 424, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 122.22, max: 281)
#
# Run: 425, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 121.96, max: 281)
#
# Run: 426, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 121.8, max: 281)
#
# Run: 427, exploration: 0.01, score: 83
# Scores: (min: 12, avg: 121.07, max: 281)
#
# Run: 428, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 120.32, max: 281)
#
# Run: 429, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 120.53, max: 281)
#
# Run: 430, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 120.55, max: 281)
#
# Run: 431, exploration: 0.01, score: 309
# Scores: (min: 12, avg: 122.36, max: 309)
#
# Run: 432, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 122.33, max: 309)
#
# Run: 433, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 122.3, max: 309)
#
# Run: 434, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 122.65, max: 309)
#
# Run: 435, exploration: 0.01, score: 129
# Scores: (min: 12, avg: 122.29, max: 309)
#
# Run: 436, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 122, max: 309)
#
# Run: 437, exploration: 0.01, score: 131
# Scores: (min: 12, avg: 122.33, max: 309)
#
# Run: 438, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 122.45, max: 309)
#
# Run: 439, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 122.62, max: 309)
#
# Run: 440, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 123, max: 309)
#
# Run: 441, exploration: 0.01, score: 102
# Scores: (min: 12, avg: 122.41, max: 309)
#
# Run: 442, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 122.34, max: 309)
#
# Run: 443, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 122.36, max: 309)
#
# Run: 444, exploration: 0.01, score: 158
# Scores: (min: 12, avg: 123.64, max: 309)
#
# Run: 445, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 123.41, max: 309)
#
# Run: 446, exploration: 0.01, score: 141
# Scores: (min: 12, avg: 123.68, max: 309)
#
# Run: 447, exploration: 0.01, score: 114
# Scores: (min: 12, avg: 124.05, max: 309)
#
# Run: 448, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 124.16, max: 309)
#
# Run: 449, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 124.15, max: 309)
#
# Run: 450, exploration: 0.01, score: 213
# Scores: (min: 12, avg: 124.98, max: 309)
#
# Run: 451, exploration: 0.01, score: 135
# Scores: (min: 12, avg: 124.76, max: 309)
#
# Run: 452, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 124.85, max: 309)
#
# Run: 453, exploration: 0.01, score: 48
# Scores: (min: 12, avg: 124.14, max: 309)
#
# Run: 454, exploration: 0.01, score: 141
# Scores: (min: 12, avg: 124, max: 309)
#
# Run: 455, exploration: 0.01, score: 214
# Scores: (min: 12, avg: 124.41, max: 309)
#
# Run: 456, exploration: 0.01, score: 233
# Scores: (min: 12, avg: 125.89, max: 309)
#
# Run: 457, exploration: 0.01, score: 52
# Scores: (min: 12, avg: 124.81, max: 309)
#
# Run: 458, exploration: 0.01, score: 19
# Scores: (min: 12, avg: 123.93, max: 309)
#
# Run: 459, exploration: 0.01, score: 252
# Scores: (min: 12, avg: 125.34, max: 309)
#
# Run: 460, exploration: 0.01, score: 108
# Scores: (min: 12, avg: 125.15, max: 309)
#
# Run: 461, exploration: 0.01, score: 327
# Scores: (min: 12, avg: 127.29, max: 327)
#
# Run: 462, exploration: 0.01, score: 125
# Scores: (min: 12, avg: 127.26, max: 327)
#
# Run: 463, exploration: 0.01, score: 132
# Scores: (min: 12, avg: 127.45, max: 327)
#
# Run: 464, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 127.02, max: 327)
#
# Run: 465, exploration: 0.01, score: 179
# Scores: (min: 12, avg: 127.81, max: 327)
#
# Run: 466, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 128.25, max: 327)
#
# Run: 467, exploration: 0.01, score: 128
# Scores: (min: 12, avg: 128.31, max: 327)
#
# Run: 468, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 128.86, max: 327)
#
# Run: 469, exploration: 0.01, score: 212
# Scores: (min: 12, avg: 130.25, max: 327)
#
# Run: 470, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 130.66, max: 327)
#
# Run: 471, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 130.84, max: 327)
#
# Run: 472, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 130.6, max: 327)
#
# Run: 473, exploration: 0.01, score: 104
# Scores: (min: 12, avg: 130.59, max: 327)
#
# Run: 474, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 130.66, max: 327)
#
# Run: 475, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 130.8, max: 327)
#
# Run: 476, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 131.6, max: 327)
#
# Run: 477, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 131.71, max: 327)
#
# Run: 478, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 132.07, max: 327)
#
# Run: 479, exploration: 0.01, score: 201
# Scores: (min: 12, avg: 133.62, max: 327)
#
# Run: 480, exploration: 0.01, score: 270
# Scores: (min: 12, avg: 136.16, max: 327)
#
# Run: 481, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 135.91, max: 327)
#
# Run: 482, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 135.9, max: 327)
#
# Run: 483, exploration: 0.01, score: 175
# Scores: (min: 12, avg: 136.74, max: 327)
#
# Run: 484, exploration: 0.01, score: 155
# Scores: (min: 12, avg: 137.16, max: 327)
#
# Run: 485, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 137.3, max: 327)
#
# Run: 486, exploration: 0.01, score: 127
# Scores: (min: 12, avg: 137.08, max: 327)
#
# Run: 487, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 137.08, max: 327)
#
# Run: 488, exploration: 0.01, score: 416
# Scores: (min: 12, avg: 139.46, max: 416)
#
# Run: 489, exploration: 0.01, score: 188
# Scores: (min: 12, avg: 139.55, max: 416)
#
# Run: 490, exploration: 0.01, score: 162
# Scores: (min: 12, avg: 139.94, max: 416)
#
# Run: 491, exploration: 0.01, score: 221
# Scores: (min: 12, avg: 140.81, max: 416)
#
# Run: 492, exploration: 0.01, score: 193
# Scores: (min: 12, avg: 141.54, max: 416)
#
# Run: 493, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 141.68, max: 416)
#
# Run: 494, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 141.39, max: 416)
#
# Run: 495, exploration: 0.01, score: 195
# Scores: (min: 12, avg: 142.05, max: 416)
#
# Run: 496, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 140.5, max: 416)
#
# Run: 497, exploration: 0.01, score: 193
# Scores: (min: 12, avg: 141.41, max: 416)
#
# Run: 498, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 141.47, max: 416)
#
# Run: 499, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 141.68, max: 416)
# Run: 500, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 141.62, max: 416)
#
# Run: 501, exploration: 0.01, score: 109
# Scores: (min: 12, avg: 141.36, max: 416)
#
# Run: 502, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 141.41, max: 416)
#
# Run: 503, exploration: 0.01, score: 172
# Scores: (min: 12, avg: 141.33, max: 416)
#
# Run: 504, exploration: 0.01, score: 154
# Scores: (min: 12, avg: 141.78, max: 416)
#
# Run: 505, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 142.04, max: 416)
#
# Run: 506, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 141.74, max: 416)
#
# Run: 507, exploration: 0.01, score: 183
# Scores: (min: 12, avg: 142.22, max: 416)
#
# Run: 508, exploration: 0.01, score: 172
# Scores: (min: 12, avg: 142.68, max: 416)
#
# Run: 509, exploration: 0.01, score: 130
# Scores: (min: 19, avg: 143.86, max: 416)
#
# Run: 510, exploration: 0.01, score: 139
# Scores: (min: 19, avg: 144.03, max: 416)
#
# Run: 511, exploration: 0.01, score: 187
# Scores: (min: 19, avg: 144.83, max: 416)
#
# Run: 512, exploration: 0.01, score: 177
# Scores: (min: 19, avg: 145.24, max: 416)
#
# Run: 513, exploration: 0.01, score: 179
# Scores: (min: 19, avg: 145.7, max: 416)
#
# Run: 514, exploration: 0.01, score: 93
# Scores: (min: 19, avg: 145.32, max: 416)
#
# Run: 515, exploration: 0.01, score: 498
# Scores: (min: 19, avg: 148.99, max: 498)
#
# Run: 516, exploration: 0.01, score: 134
# Scores: (min: 19, avg: 149.09, max: 498)
#
# Run: 517, exploration: 0.01, score: 158
# Scores: (min: 19, avg: 149.41, max: 498)
#
# Run: 518, exploration: 0.01, score: 153
# Scores: (min: 19, avg: 149.8, max: 498)
#
# Run: 519, exploration: 0.01, score: 139
# Scores: (min: 19, avg: 149.43, max: 498)
#
# Run: 520, exploration: 0.01, score: 125
# Scores: (min: 19, avg: 149.54, max: 498)
#
# Run: 521, exploration: 0.01, score: 194
# Scores: (min: 19, avg: 150.08, max: 498)
#
# Run: 522, exploration: 0.01, score: 122
# Scores: (min: 19, avg: 149.51, max: 498)
#
# Run: 523, exploration: 0.01, score: 133
# Scores: (min: 19, avg: 149.19, max: 498)
#
# Run: 524, exploration: 0.01, score: 251
# Scores: (min: 19, avg: 150.36, max: 498)
#
# Run: 525, exploration: 0.01, score: 136
# Scores: (min: 19, avg: 150.58, max: 498)
#
# Run: 526, exploration: 0.01, score: 130
# Scores: (min: 19, avg: 150.97, max: 498)
#
# Run: 527, exploration: 0.01, score: 220
# Scores: (min: 19, avg: 152.34, max: 498)
#
# Run: 528, exploration: 0.01, score: 121
# Scores: (min: 19, avg: 152.35, max: 498)
#
# Run: 529, exploration: 0.01, score: 151
# Scores: (min: 19, avg: 152.5, max: 498)
#
# Run: 530, exploration: 0.01, score: 348
# Scores: (min: 19, avg: 154.73, max: 498)
#
# Run: 531, exploration: 0.01, score: 194
# Scores: (min: 19, avg: 153.58, max: 498)
#
# Run: 532, exploration: 0.01, score: 139
# Scores: (min: 19, avg: 153.93, max: 498)
#
# Run: 533, exploration: 0.01, score: 450
# Scores: (min: 19, avg: 157.49, max: 498)
#
# Run: 534, exploration: 0.01, score: 214
# Scores: (min: 19, avg: 157.95, max: 498)
#
# Run: 535, exploration: 0.01, score: 132
# Scores: (min: 19, avg: 157.98, max: 498)
#
# Run: 536, exploration: 0.01, score: 118
# Scores: (min: 19, avg: 157.86, max: 498)
#
# Run: 537, exploration: 0.01, score: 183
# Scores: (min: 19, avg: 158.38, max: 498)
#
# Run: 538, exploration: 0.01, score: 265
# Scores: (min: 19, avg: 159.94, max: 498)
#
# Run: 539, exploration: 0.01, score: 138
# Scores: (min: 19, avg: 160.17, max: 498)
#
# Run: 540, exploration: 0.01, score: 360
# Scores: (min: 19, avg: 162.35, max: 498)
#
# Run: 541, exploration: 0.01, score: 163
# Scores: (min: 19, avg: 162.96, max: 498)
#
# Run: 542, exploration: 0.01, score: 128
# Scores: (min: 19, avg: 163.19, max: 498)
#
# Run: 543, exploration: 0.01, score: 367
# Scores: (min: 19, avg: 165.53, max: 498)
#
# Run: 544, exploration: 0.01, score: 197
# Scores: (min: 19, avg: 165.92, max: 498)
#
# Run: 545, exploration: 0.01, score: 117
# Scores: (min: 19, avg: 166, max: 498)
#
# Run: 546, exploration: 0.01, score: 197
# Scores: (min: 19, avg: 166.56, max: 498)
#
# Run: 547, exploration: 0.01, score: 225
# Scores: (min: 19, avg: 167.67, max: 498)
#
# Run: 548, exploration: 0.01, score: 164
# Scores: (min: 19, avg: 168.01, max: 498)
#
# Run: 549, exploration: 0.01, score: 117
# Scores: (min: 19, avg: 168.13, max: 498)
#
# Run: 550, exploration: 0.01, score: 135
# Scores: (min: 19, avg: 167.35, max: 498)
#
# Run: 551, exploration: 0.01, score: 148
# Scores: (min: 19, avg: 167.48, max: 498)
#
# Run: 552, exploration: 0.01, score: 195
# Scores: (min: 19, avg: 168.09, max: 498)
#
# Run: 553, exploration: 0.01, score: 243
# Scores: (min: 19, avg: 170.04, max: 498)
#
# Run: 554, exploration: 0.01, score: 164
# Scores: (min: 19, avg: 170.27, max: 498)
#
# Run: 555, exploration: 0.01, score: 134
# Scores: (min: 19, avg: 169.47, max: 498)
#
# Run: 556, exploration: 0.01, score: 24
# Scores: (min: 19, avg: 167.38, max: 498)
#
# Run: 557, exploration: 0.01, score: 69
# Scores: (min: 19, avg: 167.55, max: 498)
#
# Run: 558, exploration: 0.01, score: 122
# Scores: (min: 24, avg: 168.58, max: 498)
#
# Run: 559, exploration: 0.01, score: 199
# Scores: (min: 24, avg: 168.05, max: 498)
#
# Run: 560, exploration: 0.01, score: 103
# Scores: (min: 24, avg: 168, max: 498)
#
# Run: 561, exploration: 0.01, score: 181
# Scores: (min: 24, avg: 166.54, max: 498)
#
# Run: 562, exploration: 0.01, score: 126
# Scores: (min: 24, avg: 166.55, max: 498)
#
# Run: 563, exploration: 0.01, score: 175
# Scores: (min: 24, avg: 166.98, max: 498)
#
# Run: 564, exploration: 0.01, score: 222
# Scores: (min: 24, avg: 168.17, max: 498)
#
# Run: 565, exploration: 0.01, score: 176
# Scores: (min: 24, avg: 168.14, max: 498)
#
# Run: 566, exploration: 0.01, score: 283
# Scores: (min: 24, avg: 169.22, max: 498)
#
# Run: 567, exploration: 0.01, score: 112
# Scores: (min: 24, avg: 169.06, max: 498)
#
# Run: 568, exploration: 0.01, score: 134
# Scores: (min: 24, avg: 168.72, max: 498)
#
# Run: 569, exploration: 0.01, score: 390
# Scores: (min: 24, avg: 170.5, max: 498)
#
# Run: 570, exploration: 0.01, score: 258
# Scores: (min: 24, avg: 171.66, max: 498)
#
# Run: 571, exploration: 0.01, score: 182
# Scores: (min: 24, avg: 172.37, max: 498)
#
# Run: 572, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 176.36, max: 500)
#
# Run: 573, exploration: 0.01, score: 156
# Scores: (min: 24, avg: 176.88, max: 500)
#
# Run: 574, exploration: 0.01, score: 142
# Scores: (min: 24, avg: 177.14, max: 500)
#
# Run: 575, exploration: 0.01, score: 148
# Scores: (min: 24, avg: 177.25, max: 500)
#
# Run: 576, exploration: 0.01, score: 234
# Scores: (min: 24, avg: 178.43, max: 500)
#
# Run: 577, exploration: 0.01, score: 135
# Scores: (min: 24, avg: 178.48, max: 500)
#
# Run: 578, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 182.05, max: 500)
#
# Run: 579, exploration: 0.01, score: 469
# Scores: (min: 24, avg: 184.73, max: 500)
#
# Run: 580, exploration: 0.01, score: 95
# Scores: (min: 24, avg: 182.98, max: 500)
#
# Run: 581, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 186.78, max: 500)
#
# Run: 582, exploration: 0.01, score: 87
# Scores: (min: 24, avg: 186.66, max: 500)
#
# Run: 583, exploration: 0.01, score: 167
# Scores: (min: 24, avg: 186.58, max: 500)
#
# Run: 584, exploration: 0.01, score: 147
# Scores: (min: 24, avg: 186.5, max: 500)
#
# Run: 585, exploration: 0.01, score: 112
# Scores: (min: 24, avg: 186.46, max: 500)
#
# Run: 586, exploration: 0.01, score: 500
# Scores: (min: 24, avg: 190.19, max: 500)
#
# Run: 587, exploration: 0.01, score: 138
# Scores: (min: 24, avg: 190.4, max: 500)
#
# Run: 588, exploration: 0.01, score: 126
# Scores: (min: 24, avg: 187.5, max: 500)
#
# Run: 589, exploration: 0.01, score: 133
# Scores: (min: 24, avg: 186.95, max: 500)
#
# Run: 590, exploration: 0.01, score: 158
# Scores: (min: 24, avg: 186.91, max: 500)
#
# Run: 591, exploration: 0.01, score: 285
# Scores: (min: 24, avg: 187.55, max: 500)
#
# Run: 592, exploration: 0.01, score: 127
# Scores: (min: 24, avg: 186.89, max: 500)
#
# Run: 593, exploration: 0.01, score: 122
# Scores: (min: 24, avg: 186.88, max: 500)
#
# Run: 594, exploration: 0.01, score: 168
# Scores: (min: 24, avg: 187.69, max: 500)
#
# Run: 595, exploration: 0.01, score: 146
# Scores: (min: 24, avg: 187.2, max: 500)
#
# Run: 596, exploration: 0.01, score: 192
# Scores: (min: 24, avg: 187.86, max: 500)
#
# Run: 597, exploration: 0.01, score: 27
# Scores: (min: 24, avg: 186.2, max: 500)
#
# Run: 598, exploration: 0.01, score: 130
# Scores: (min: 24, avg: 186.3, max: 500)
#
# Run: 599, exploration: 0.01, score: 120
# Scores: (min: 24, avg: 186.31, max: 500)
#
# Run: 600, exploration: 0.01, score: 207
# Scores: (min: 24, avg: 187.33, max: 500)
# Run: 601, exploration: 0.01, score: 227
# Scores: (min: 24, avg: 188.51, max: 500)
#
# Run: 602, exploration: 0.01, score: 54
# Scores: (min: 24, avg: 187.79, max: 500)
#
# Run: 603, exploration: 0.01, score: 18
# Scores: (min: 18, avg: 186.25, max: 500)
#
# Run: 604, exploration: 0.01, score: 39
# Scores: (min: 18, avg: 185.1, max: 500)
#
# Run: 605, exploration: 0.01, score: 96
# Scores: (min: 18, avg: 184.41, max: 500)
#
# Run: 606, exploration: 0.01, score: 122
# Scores: (min: 18, avg: 184.43, max: 500)
#
# Run: 607, exploration: 0.01, score: 187
# Scores: (min: 18, avg: 184.47, max: 500)
#
# Run: 608, exploration: 0.01, score: 117
# Scores: (min: 18, avg: 183.92, max: 500)
#
# Run: 609, exploration: 0.01, score: 138
# Scores: (min: 18, avg: 184, max: 500)
#
# Run: 610, exploration: 0.01, score: 500
# Scores: (min: 18, avg: 187.61, max: 500)
#
# Run: 611, exploration: 0.01, score: 140
# Scores: (min: 18, avg: 187.14, max: 500)
#
# Run: 612, exploration: 0.01, score: 232
# Scores: (min: 18, avg: 187.69, max: 500)
#
# Run: 613, exploration: 0.01, score: 474
# Scores: (min: 18, avg: 190.64, max: 500)
#
# Run: 614, exploration: 0.01, score: 210
# Scores: (min: 18, avg: 191.81, max: 500)
#
# Run: 615, exploration: 0.01, score: 154
# Scores: (min: 18, avg: 188.37, max: 500)
#
# Run: 616, exploration: 0.01, score: 393
# Scores: (min: 18, avg: 190.96, max: 500)
#
# Run: 617, exploration: 0.01, score: 134
# Scores: (min: 18, avg: 190.72, max: 500)
#
# Run: 618, exploration: 0.01, score: 167
# Scores: (min: 18, avg: 190.86, max: 500)
#
# Run: 619, exploration: 0.01, score: 200
# Scores: (min: 18, avg: 191.47, max: 500)
#
# Run: 620, exploration: 0.01, score: 200
# Scores: (min: 18, avg: 192.22, max: 500)
#
# Run: 621, exploration: 0.01, score: 207
# Scores: (min: 18, avg: 192.35, max: 500)
#
# Run: 622, exploration: 0.01, score: 146
# Scores: (min: 18, avg: 192.59, max: 500)
#
# Run: 623, exploration: 0.01, score: 110
# Scores: (min: 18, avg: 192.36, max: 500)
#
# Run: 624, exploration: 0.01, score: 132
# Scores: (min: 18, avg: 191.17, max: 500)
#
# Run: 625, exploration: 0.01, score: 126
# Scores: (min: 18, avg: 191.07, max: 500)
#
# Run: 626, exploration: 0.01, score: 244
# Scores: (min: 18, avg: 192.21, max: 500)
#
# Run: 627, exploration: 0.01, score: 118
# Scores: (min: 18, avg: 191.19, max: 500)
#
# Run: 628, exploration: 0.01, score: 500
# Scores: (min: 18, avg: 194.98, max: 500)
#
# Run: 629, exploration: 0.01, score: 309
# Scores: (min: 18, avg: 196.56, max: 500)
#
# Solved in 529 runs, 629 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-28194e7febc7> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# For this RL example the agent is trying balance the inverted pendulum and is represeneted by the solver, DQNSolver The possible state values describe the cart position, velocity, pole angle and its tip velocity. The actions describe what the cart can do to change the position o fthe pole, e.g., move left or move right
#
# This exmaple of RL uses the DQN (Deep Q-Learning) as its reinforcement algorithm and uses the DQNSolver.
# This algorithm uses experience replay (line 88) so that the states experienced by the agent can be remembered and then have those experiences sampled. By sampling the algorithm tries to "reduce correlation between subsequent actions".
#
# This algorithm also uses a discount factor that is not myopic, i.e., 0.95. The discount factor determines the importance of future rewards. A factor of 0 will make the agent short-sighted by only considering current rewards, while a factor approaching 1 will make it strive for a long-term high reward.
#
# In long running training sessions, or models with many, many states the Q-table may become too large to fit into memory or be efficiently searched. A neural network may be substituted for this table to approximate the response with the Q-values computed using the Bellman equation.
#
# With the default learning rate, alpha, (0.001) the algorithm finished in 125 runs. At 0.0001 192 were needed ahd at 0.01 more than 784 were need - simulation was termintaed at 784 runs. The learning rate is the "step size". If the step size is too large the simulation can meander around the minimum without converging - which is what happened at 0.01. In theory, a large step size is useful at the beginning of the run so expericnce is gained quickly but becomes detrimental later on. The decay factor could be changed so that the learning rate is high to start and less as the simulation progresses.
#
#
# Surma, G. (2021). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. Retrieved from https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
#
# Q-learning. (2023, March 28).  In Wikipedia. https://en.wikipedia.org/w/index.php?title=Q-learning&oldid=1146994709
